# %% [markdown]
# # Dans ce Notebook, on se propose de regarder les différentes surfaces cultivées de chaque culture déclarée par les agriculteurs en mode "réalisé".

# %% [markdown]
# # Partie générique

# %% [markdown]
# ### Imports

# %%
# en cas de problème d'import, installer le module manquant en décommentant la ligne suivante et remplacant par le nom du module
# !pip install [MODULE_MANQUANT]

import numpy as np
import pandas
from collections import defaultdict, Counter
from pathlib import Path
from itertools import chain
from tqdm import tqdm
import re
import matplotlib.pyplot as plt

# %% [markdown]
# ### Chemin des données exportées de Datagrosyst [A ADAPTER]

# %%
# les fichiers csv sont dans ce dossier
DATA_FOLDER_PATH = '/home/administrateur/Documents/datagrosyst' # [A ADAPTER]

# %% [markdown]
# ### Définitions utiles

# %%
data_folder = Path(DATA_FOLDER_PATH)

def load_df(nom):
    """
        vient charger une dataframe avec le fichier Datagrosyst du bon nom
    """
    return pandas.read_csv(data_folder / (nom+'.csv'), index_col='id')

# %% [markdown]
# ### Définition des tables à charger [A ADAPTER]

# %%
data_names = {}

data_names['context']            = ['sdc', 'parcelle', 'zone', 'synthetise', 'sole_realise',] # [A ADAPTER]
data_names['intervention']       = ['noeuds_realise',] # [A ADAPTER]
data_names['intrant_&_culture']  = ['culture', 'semence', 'composant_culture',] # [A ADAPTER]
data_names['modele_decisionnel'] = [] # [A ADAPTER]
data_names['bilan_de_campagne']  = [] # [A ADAPTER]
data_names['performance']        = [] # [A ADAPTER]
data_names['referentiel']        = ['espece',] # [A ADAPTER]

# %% [markdown]
# ### Charment des données

# %%
# Loader des dataframes
df = {}

for data_name in chain(*data_names.values()):
    df[data_name] = load_df(data_name)

# %% [markdown]
# # Etude de la répartition des espèces cultivées (systèmes réalisés)

# %% [markdown]
# ### Traitement

# %%
compoant_culture_by_culture_id = df['composant_culture'].groupby(['culture_id'])
cultures_sans_composant_associe = []
soles_avec_culture_indefinie = []

surfaces_occupees = defaultdict(float)

for sole_realise in tqdm(df['sole_realise'].itertuples(), desc='Parcours des soles en realise', total=len(df['sole_realise'])):
    # zone
    zone = df['zone'].loc[sole_realise.zone_id]
    surface_zone = zone['surface']
    
    # espece
    culture = df['culture'].loc[sole_realise.culture_id] # millesimé
    # culture_code = culture['code'] # non millesimé (peut représenter différentes cultures réelles selon les années)
    if not sole_realise.culture_id in compoant_culture_by_culture_id.groups:
        soles_avec_culture_indefinie.append(sole_realise)
        cultures_sans_composant_associe.append(culture)
        surfaces_occupees['INDEFINI'] += surface_zone
        continue

    composants_culture = compoant_culture_by_culture_id.get_group(sole_realise.culture_id)
    for composant_culture in composants_culture.itertuples(index=False):
        espece = df['espece'].loc[composant_culture.espece_id]
        nom_espece = espece['libelle_espece_botanique']
        proportion_espece = composant_culture.surface_relative
        if proportion_espece != proportion_espece:
            proportion_espece = 100/len(composants_culture)

        surfaces_occupees[nom_espece] += surface_zone * proportion_espece / 100

# on trie par especes les plus utilisees
surfaces_occupees = dict(sorted(surfaces_occupees.items(), key=lambda item: item[1], reverse=True))

print()
for nom_espece, surface_occupee in surfaces_occupees.items():
    print(f'L espèce "{nom_espece:^30}" a été cultivée sur {surface_occupee:7.0f} Ha [{(100*surface_occupee / sum(surfaces_occupees.values())):2.1f} %]')
# Out:
# Parcours des soles en realise:   0%|          | 0/112372 [00:00<?, ?it/s]
# Parcours des soles en realise: 100%|██████████| 112372/112372 [00:41<00:00, 2740.15it/s]
# L espèce "          Blé tendre          " a été cultivée sur  189949 Ha [30.4 %]
# L espèce "             Maïs             " a été cultivée sur   85631 Ha [13.7 %]
# L espèce "             Orge             " a été cultivée sur   79328 Ha [12.7 %]
# L espèce "            Colza             " a été cultivée sur   61110 Ha [9.8 %]
# L espèce "           Prairie            " a été cultivée sur   32179 Ha [5.2 %]
# L espèce "          Betterave           " a été cultivée sur   21193 Ha [3.4 %]
# L espèce "          Tournesol           " a été cultivée sur   20061 Ha [3.2 %]
# L espèce "             Pois             " a été cultivée sur   18190 Ha [2.9 %]
# L espèce "           Luzerne            " a été cultivée sur   13550 Ha [2.2 %]
# L espèce "             Soja             " a été cultivée sur   10703 Ha [1.7 %]
# L espèce "           Fèverole           " a été cultivée sur    9125 Ha [1.5 %]
# L espèce "        Pomme de terre        " a été cultivée sur    8447 Ha [1.4 %]
# L espèce "          Triticale           " a été cultivée sur    8378 Ha [1.3 %]
# L espèce "           Blé dur            " a été cultivée sur    7220 Ha [1.2 %]
# L espèce "             Lin              " a été cultivée sur    6756 Ha [1.1 %]
# L espèce "       Espèces diverses       " a été cultivée sur    4511 Ha [0.7 %]
# L espèce "            Avoine            " a été cultivée sur    3447 Ha [0.6 %]
# L espèce "           Lentille           " a été cultivée sur    3139 Ha [0.5 %]
# L espèce "           Chanvre            " a été cultivée sur    2909 Ha [0.5 %]
# L espèce "            Sorgho            " a été cultivée sur    2779 Ha [0.4 %]
# L espèce "      Mélange Fourrager       " a été cultivée sur    2599 Ha [0.4 %]
# L espèce "      Ray-grass d'Italie      " a été cultivée sur    2556 Ha [0.4 %]
# L espèce "           INDEFINI           " a été cultivée sur    2516 Ha [0.4 %]
# L espèce "        Trèfle violet         " a été cultivée sur    2372 Ha [0.4 %]
# L espèce "            Seigle            " a été cultivée sur    2056 Ha [0.3 %]
# L espèce "           Sarrasin           " a été cultivée sur    1808 Ha [0.3 %]
# L espèce "           Haricot            " a été cultivée sur    1763 Ha [0.3 %]
# L espèce "         Trèfle blanc         " a été cultivée sur    1634 Ha [0.3 %]
# L espèce "      Ray-grass anglais       " a été cultivée sur    1384 Ha [0.2 %]
# L espèce "           Dactyle            " a été cultivée sur    1040 Ha [0.2 %]
# L espèce "      Ray-grass hybride       " a été cultivée sur    1002 Ha [0.2 %]
# L espèce "           Mélange            " a été cultivée sur     949 Ha [0.2 %]
# L espèce "       Trèfle incarnat        " a été cultivée sur     908 Ha [0.1 %]
# L espèce "        Millet commun         " a été cultivée sur     900 Ha [0.1 %]
# L espèce "        Vesce commune         " a été cultivée sur     844 Ha [0.1 %]
# L espèce "             Ail              " a été cultivée sur     798 Ha [0.1 %]
# L espèce "         Pois chiche          " a été cultivée sur     752 Ha [0.1 %]
# L espèce "           Epeautre           " a été cultivée sur     660 Ha [0.1 %]
# L espèce "           Chicorée           " a été cultivée sur     650 Ha [0.1 %]
# L espèce "        Moutarde brune        " a été cultivée sur     563 Ha [0.1 %]
# L espèce "            Oignon            " a été cultivée sur     545 Ha [0.1 %]
# L espèce "      Oeillette (pavot)       " a été cultivée sur     536 Ha [0.1 %]
# L espèce "           Carotte            " a été cultivée sur     448 Ha [0.1 %]
# L espèce "       Moutarde blanche       " a été cultivée sur     423 Ha [0.1 %]
# L espèce "      Avoine brésilienne      " a été cultivée sur     416 Ha [0.1 %]
# L espèce "        Fétuque élevée        " a été cultivée sur     413 Ha [0.1 %]
# L espèce "     Trèfle d'Alexandrie      " a été cultivée sur     393 Ha [0.1 %]
# L espèce "         Lupin blanc          " a été cultivée sur     392 Ha [0.1 %]
# L espèce "       Fétuque des prés       " a été cultivée sur     287 Ha [0.0 %]
# L espèce "             Chou             " a été cultivée sur     239 Ha [0.0 %]
# L espèce "         Chrysanthème         " a été cultivée sur     200 Ha [0.0 %]
# L espèce "       Fléole des prés        " a été cultivée sur     186 Ha [0.0 %]
# L espèce "           Cameline           " a été cultivée sur     174 Ha [0.0 %]
# L espèce "             Riz              " a été cultivée sur     174 Ha [0.0 %]
# L espèce "           Phacélie           " a été cultivée sur     171 Ha [0.0 %]
# L espèce "        Autre graminée        " a été cultivée sur     159 Ha [0.0 %]
# L espèce "           Sainfoin           " a été cultivée sur     145 Ha [0.0 %]
# L espèce "      Mélange Graminées       " a été cultivée sur     133 Ha [0.0 %]
# L espèce "  Moha ou Millet des oiseaux  " a été cultivée sur     123 Ha [0.0 %]
# L espèce "            Lotier            " a été cultivée sur     114 Ha [0.0 %]
# L espèce "            Radis             " a été cultivée sur     109 Ha [0.0 %]
# L espèce "     Mélange Floristique      " a été cultivée sur     105 Ha [0.0 %]
# L espèce "      Autre légumineuse       " a été cultivée sur      98 Ha [0.0 %]
# L espèce "           Fraisier           " a été cultivée sur      97 Ha [0.0 %]
# L espèce "           Epinard            " a été cultivée sur      96 Ha [0.0 %]
# L espèce "          Coriandre           " a été cultivée sur      92 Ha [0.0 %]
# L espèce "           Fenugrec           " a été cultivée sur      90 Ha [0.0 %]
# L espèce "         Vesce Velue          " a été cultivée sur      84 Ha [0.0 %]
# L espèce "          Lupin bleu          " a été cultivée sur      83 Ha [0.0 %]
# L espèce "          Artichaut           " a été cultivée sur      82 Ha [0.0 %]
# L espèce "       Seigle forestier       " a été cultivée sur      82 Ha [0.0 %]
# L espèce "        Trèfle hybride        " a été cultivée sur      75 Ha [0.0 %]
# L espèce "        Mélange chasse        " a été cultivée sur      72 Ha [0.0 %]
# L espèce "           Poireau            " a été cultivée sur      65 Ha [0.0 %]
# L espèce "          Miscanthus          " a été cultivée sur      60 Ha [0.0 %]
# L espèce "            Tomate            " a été cultivée sur      58 Ha [0.0 %]
# L espèce "           Petunia            " a été cultivée sur      50 Ha [0.0 %]
# L espèce "         Calibrachoa          " a été cultivée sur      50 Ha [0.0 %]
# L espèce "         Pelargonium          " a été cultivée sur      50 Ha [0.0 %]
# L espèce "       Autres Potagères       " a été cultivée sur      50 Ha [0.0 %]
# L espèce "       Ray-grass annuel       " a été cultivée sur      49 Ha [0.0 %]
# L espèce "            Laitue            " a été cultivée sur      48 Ha [0.0 %]
# L espèce "        Pâturin commun        " a été cultivée sur      44 Ha [0.0 %]
# L espèce " Gesse Commune ou pois carré  " a été cultivée sur      40 Ha [0.0 %]
# L espèce "           Echalote           " a été cultivée sur      40 Ha [0.0 %]
# L espèce "            Vigne             " a été cultivée sur      40 Ha [0.0 %]
# L espèce "       Trèfle de Perse        " a été cultivée sur      38 Ha [0.0 %]
# L espèce "           Chardon            " a été cultivée sur      38 Ha [0.0 %]
# L espèce "            Quinoa            " a été cultivée sur      37 Ha [0.0 %]
# L espèce "   Engrain (Petit épeautre)   " a été cultivée sur      36 Ha [0.0 %]
# L espèce "          Concombre           " a été cultivée sur      35 Ha [0.0 %]
# L espèce "          Avoine nue          " a été cultivée sur      33 Ha [0.0 %]
# L espèce "           Navette            " a été cultivée sur      33 Ha [0.0 %]
# L espèce "      Trèfle squarrosum       " a été cultivée sur      31 Ha [0.0 %]
# L espèce "       Lotier corniculé       " a été cultivée sur      28 Ha [0.0 %]
# L espèce "      Trèfle souterrain       " a été cultivée sur      27 Ha [0.0 %]
# L espèce "      Mélange Pollinique      " a été cultivée sur      23 Ha [0.0 %]
# L espèce "           Minette            " a été cultivée sur      23 Ha [0.0 %]
# L espèce "       Trèfle aggloméré       " a été cultivée sur      22 Ha [0.0 %]
# L espèce "       Brome de champs        " a été cultivée sur      19 Ha [0.0 %]
# L espèce "           Pommier            " a été cultivée sur      18 Ha [0.0 %]
# L espèce "            Noyer             " a été cultivée sur      18 Ha [0.0 %]
# L espèce "           Salsifis           " a été cultivée sur      18 Ha [0.0 %]
# L espèce "        Fétuque rouge         " a été cultivée sur      17 Ha [0.0 %]
# L espèce "      Plantain lancéolé       " a été cultivée sur      16 Ha [0.0 %]
# L espèce "Niébé Cowpea ou Voème Haricot kilomètre" a été cultivée sur      16 Ha [0.0 %]
# L espèce "           Fenouil            " a été cultivée sur      14 Ha [0.0 %]
# L espèce "     Autres ornementales      " a été cultivée sur      13 Ha [0.0 %]
# L espèce "            Cardon            " a été cultivée sur      12 Ha [0.0 %]
# L espèce "            Courge            " a été cultivée sur      11 Ha [0.0 %]
# L espèce "       Avoine byzantine       " a été cultivée sur      11 Ha [0.0 %]
# L espèce "      Trèfle de Micheli       " a été cultivée sur      10 Ha [0.0 %]
# L espèce "             Chia             " a été cultivée sur      10 Ha [0.0 %]
# L espèce "            Navet             " a été cultivée sur       8 Ha [0.0 %]
# L espèce "       Sauge officinale       " a été cultivée sur       8 Ha [0.0 %]
# L espèce "            Nyger             " a été cultivée sur       7 Ha [0.0 %]
# L espèce "            Persil            " a été cultivée sur       7 Ha [0.0 %]
# L espèce "       Vesce du Bengale       " a été cultivée sur       7 Ha [0.0 %]
# L espèce "       Pâturin des prés       " a été cultivée sur       7 Ha [0.0 %]
# L espèce "          Courgette           " a été cultivée sur       7 Ha [0.0 %]
# L espèce "         Framboisier          " a été cultivée sur       6 Ha [0.0 %]
# L espèce "            Lablab            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Potiron            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "          Aubergine           " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Asperge            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "             Anis             " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Carthame           " a été cultivée sur       5 Ha [0.0 %]
# L espèce "            Panais            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "           Oseille            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "            Céleri            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "        Canne à sucre         " a été cultivée sur       4 Ha [0.0 %]
# L espèce "         Brome dressé         " a été cultivée sur       4 Ha [0.0 %]
# L espèce "       Fléole bulbeuse        " a été cultivée sur       4 Ha [0.0 %]
# L espèce "            Aneth             " a été cultivée sur       4 Ha [0.0 %]
# L espèce "           Prunier            " a été cultivée sur       4 Ha [0.0 %]
# L espèce "           Lavande            " a été cultivée sur       4 Ha [0.0 %]
# L espèce "             Thym             " a été cultivée sur       4 Ha [0.0 %]
# L espèce "       Trèfle vésiculé        " a été cultivée sur       4 Ha [0.0 %]
# L espèce "      Vesce de Narbonne       " a été cultivée sur       3 Ha [0.0 %]
# L espèce "            Melon             " a été cultivée sur       3 Ha [0.0 %]
# L espèce "           Peuplier           " a été cultivée sur       3 Ha [0.0 %]
# L espèce "            Saule             " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Mélisse            " a été cultivée sur       2 Ha [0.0 %]
# L espèce "        Pâturin annuel        " a été cultivée sur       2 Ha [0.0 %]
# L espèce "          Angélique           " a été cultivée sur       2 Ha [0.0 %]
# L espèce "            Aulne             " a été cultivée sur       2 Ha [0.0 %]
# L espèce "     Matricaire camomille     " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Cerisier           " a été cultivée sur       2 Ha [0.0 %]
# L espèce "             Fève             " a été cultivée sur       2 Ha [0.0 %]
# L espèce "         Trèfle strié         " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Poirier            " a été cultivée sur       2 Ha [0.0 %]
# L espèce "          Abricotier          " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Pêcher            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Sapin             " a été cultivée sur       1 Ha [0.0 %]
# L espèce "          Bourrache           " a été cultivée sur       1 Ha [0.0 %]
# L espèce "           Romarin            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "       Plantain majeur        " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Ananas            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "           Statice            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "        Lagerstroemia         " a été cultivée sur       1 Ha [0.0 %]
# L espèce "     Lentille fourragère      " a été cultivée sur       1 Ha [0.0 %]
# L espèce "  Panic érigé (switch grass)  " a été cultivée sur       1 Ha [0.0 %]
# L espèce "         Patate douce         " a été cultivée sur       1 Ha [0.0 %]
# L espèce "        Trèfle hérissé        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Litchi            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Poivrier noir         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Mâche             " a été cultivée sur       0 Ha [0.0 %]
# L espèce " Dauphinelle à grandes fleurs " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Crotalaria          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Vanille            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Piment Poivron        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Millet perlé         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Brachiaria ruziziensis     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Pastèque           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Igname            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Fruit de la passion      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Curcuma            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Gingembre           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Mélilot officinal       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Chou chinois         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Prunier de Cythère      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Roquette           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Alchémille          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Lisianthus          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Bananier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Gombo             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "    Ciboule ou Oignon pays    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Pois sabre          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Rosier multiflore       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Pois doux           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Souci             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Basilic            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Papayer            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Cacaoyer commun        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Gerbera            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "Hibiscus sabdariffa ou Groseille péyi" a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Figuier            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Manguier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Arachide           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Moutarde d'abyssinie     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "    Vipérine faux plantain    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Centaurée bleuet       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Fétuque ovine         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Centaurée           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Reine marguerite       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Tanaisie = chrysanthème    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Alliaire           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Rosier            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Chayotte = Christophine    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Attier Pomme Canelle     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Anémone            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "  Pomme Liane ou Grenadille   " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Primevère           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Giroflée ravenelle      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Pensée            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Arbousier commun       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Myrthe ou myrte        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Pittosporum          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Cistus            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Choisya            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Arbre à pain         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Groseiller          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Menthe            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Estragon           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Ciboulette          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Campanule           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Heuchère           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Rose d'Inde          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Myosotis           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Noisetier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Chêne             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Hêtre             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Viorne            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Châtaignier          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Charme            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Sureau            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Cornus            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Potentille          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Œillet d'Inde         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Immortelle          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Jasmin            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Manioc            " a été cultivée sur       0 Ha [0.0 %]

# %% [markdown]
# ### Graphique

# %%
# Diagramme camembert
plt.figure(figsize=(8, 8)) # Taille du diagramme
plt.pie(surfaces_occupees.values(), labels=surfaces_occupees.keys(), autopct='%1.1f%%', startangle=140)

plt.title('Répartition des surfaces cultivées ("saisies réalisé")dans Agrosyst')
plt.axis('equal') # Permet d'avoir un diagramme circulaire plutôt qu'elliptique
plt.show()

# %% [markdown]
# # Pour aller plus loin

# %% [markdown]
# ### => On essaie d'identifier les cultures renseignées sans especes associées

# %%
soles_avec_culture_indefinie = pandas.DataFrame(soles_avec_culture_indefinie)
cultures_sans_composant_associe = pandas.DataFrame(cultures_sans_composant_associe)

noms_saisis_aggreges = Counter(cultures_sans_composant_associe['nom'])

print(f'Il y a {len(cultures_sans_composant_associe)} cultures saisies sans composants associés.\n')
print('Les noms (champ libre) renseignés sont :\n')

for element, count in noms_saisis_aggreges.most_common():
    print(f"   {element:<25}: {count} saisies")
# Out:
# Il y a 787 cultures saisies sans composants associés.
#
# Les noms (champ libre) renseignés sont :
#
#    Jachère                  : 84 saisies
#    Jachère > 5 ans          : 47 saisies
#    Jachère de 6 ans ou plus : 39 saisies
#    Blé                      : 33 saisies
#    PRAIRIE TEMPORAIRE       : 31 saisies
#    Vide sanitaire           : 24 saisies
#    Espèces diverses         : 14 saisies
#    Prairie temporaire       : 13 saisies
#    prairie temporaire       : 13 saisies
#    Tournesol                : 12 saisies
#    Soja                     : 12 saisies
#    Colza                    : 11 saisies
#    Plante de service        : 10 saisies
#    plante de service        : 10 saisies
#    Méteil de printemps      : 9 saisies
#    MAIS GRAIN               : 9 saisies
#    sainfoin                 : 9 saisies
#    Moutarde                 : 7 saisies
#    Féverole                 : 7 saisies
#    Prairie permanente       : 7 saisies
#    Prairie Temporaire       : 7 saisies
#    CROTALAIRE               : 6 saisies
#    maïs ensilage            : 6 saisies
#    Eleusine                 : 6 saisies
#    Alysse                   : 6 saisies
#    ble tendre               : 6 saisies
#    Blette                   : 6 saisies
#    OP                       : 6 saisies
#    Souci                    : 6 saisies
#    Jachère et gel melifere  : 6 saisies
#    Ail                      : 6 saisies
#    MUSCARI                  : 6 saisies
#    Jachère 6 ans ou plus ou temporaire: 5 saisies
#    Espèce diverse           : 5 saisies
#    ORGE DE PRINTEMPS        : 5 saisies
#    Friche                   : 5 saisies
#    Orge Printemps           : 5 saisies
#    orge de printemps        : 5 saisies
#    COLZA                    : 5 saisies
#    Luzerne                  : 4 saisies
#    Jachère floristique de 5 ans ou moins: 4 saisies
#    Haie endémique           : 4 saisies
#    PT (PT)                  : 4 saisies
#    MAIS FOURRAGE            : 4 saisies
#    Pois                     : 4 saisies
#    Blé tendre d'hiver       : 4 saisies
#    SONGE GRISE              : 4 saisies
#    Jachère permanente       : 4 saisies
#    calebasse                : 4 saisies
#    Avoine                   : 4 saisies
#    Sarrasin                 : 3 saisies
#    Sainfoin mélange ferme   : 3 saisies
#    PT                       : 3 saisies
#    orge hiver               : 3 saisies
#    Triticale                : 3 saisies
#    Jachère en légumineuses  : 3 saisies
#    Corossol                 : 3 saisies
#    prairie                  : 3 saisies
#    Grenadier                : 3 saisies
#    PRAIRIES TEMPORAIRE      : 3 saisies
#    Melon                    : 3 saisies
#    renoncule                : 3 saisies
#    Jachère en graminées     : 3 saisies
#    Aubergine                : 3 saisies
#    Célosie                  : 3 saisies
#    Pois chiche              : 3 saisies
#    Giroflée                 : 3 saisies
#    Orge                     : 3 saisies
#    Muflier                  : 3 saisies
#    Salade                   : 3 saisies
#    soja                     : 3 saisies
#    Avocatier                : 3 saisies
#    noyer                    : 3 saisies
#    Pastèque                 : 3 saisies
#    Culture dérobée          : 2 saisies
#    dachine                  : 2 saisies
#    RGI + Trefle             : 2 saisies
#    Geranium vivaces         : 2 saisies
#    seigle                   : 2 saisies
#    ray grass d'italie       : 2 saisies
#    Citronnelle              : 2 saisies
#    Blé tendre               : 2 saisies
#    TREFLE D'ALEXANDRIE      : 2 saisies
#    jachère                  : 2 saisies
#    RGA                      : 2 saisies
#    crotalaire               : 2 saisies
#    DAE Maïs                 : 2 saisies
#    Maïs semence Hors Altercarot: 2 saisies
#    Haricot noir             : 2 saisies
#    Précédent fictif         : 2 saisies
#    zone enherbée            : 2 saisies
#    Quinoa                   : 2 saisies
#    Vétiver                  : 2 saisies
#    TOURNESOL                : 2 saisies
#    Sorgho                   : 2 saisies
#    autres cépages           : 2 saisies
#    Trèfle pur               : 2 saisies
#    Friche agricole          : 2 saisies
#    Citrouille péi et butternut: 2 saisies
#    Blé d'oeillette          : 2 saisies
#    Maïs                     : 2 saisies
#    Orge d'hiver             : 2 saisies
#    Orge d'orge              : 2 saisies
#    Lin fibre                : 2 saisies
#    Sainfoin                 : 2 saisies
#    HARICOT EMERITE          : 2 saisies
#    Orge de Printemps        : 2 saisies
#    Parcours                 : 2 saisies
#    FEVEROLES                : 2 saisies
#    Méteil                   : 2 saisies
#    Orge Hiver               : 2 saisies
#    trèfle violet            : 2 saisies
#    PDS AROMATES             : 2 saisies
#    Gerbera Divers 2         : 2 saisies
#    ORGE                     : 2 saisies
#    Millet                   : 2 saisies
#    pois printemps           : 2 saisies
#    Culture légumière : melons / céleris / légumes: 2 saisies
#    Trèfle semence           : 2 saisies
#    Lagerstroemia godet      : 1 saisies
#    Soja Astafor dérobé      : 1 saisies
#    Cyclamen                 : 1 saisies
#    Plantes en pot de diversification de printemps: 1 saisies
#    JACHERE                  : 1 saisies
#    RG-Trèfle                : 1 saisies
#    melange melivert         : 1 saisies
#    ROSIER                   : 1 saisies
#    Songe 1 divers           : 1 saisies
#    Blé dur d'hiver          : 1 saisies
#    Gamme arbuste - Perovskia + Exochorda: 1 saisies
#    Triticale depuis 2001    : 1 saisies
#    Conteneur                : 1 saisies
#    Trèfle (semence)         : 1 saisies
#    Viola                    : 1 saisies
#    Gel                      : 1 saisies
#    lisianthus               : 1 saisies
#    Colza oléagineux Hiver   : 1 saisies
#    Verger pour Greffons     : 1 saisies
#    pavot                    : 1 saisies
#    VETIVER                  : 1 saisies
#    Citrouille               : 1 saisies
#    méteil                   : 1 saisies
#    Citrouille péi           : 1 saisies
#    Haricots                 : 1 saisies
#    blé tendre               : 1 saisies
#    Blé dur                  : 1 saisies
#    Prairie pâturée depuis 2016: 1 saisies
#    SOJA                     : 1 saisies
#    Orge hiver               : 1 saisies
#    Escourgeon               : 1 saisies
#    Trèfle alexandrie semences: 1 saisies
#    Pomme de terre           : 1 saisies
#    Tomate                   : 1 saisies
#    Chrysanthème             : 1 saisies
#    Camelia en C4L           : 1 saisies
#    pleine terre Bruyères    : 1 saisies
#    Chou fleur               : 1 saisies
#    Jachère depuis 2010      : 1 saisies
#    Orge d'Hiver             : 1 saisies
#    TRITICALE                : 1 saisies
#    Tritical                 : 1 saisies
#    mais fourrager           : 1 saisies
#    Seigle                   : 1 saisies
#    Petits Fruitiers         : 1 saisies
#    FEVEROLLE DE PRINTEMPS   : 1 saisies
#    AIL                      : 1 saisies
#    Maïs grain               : 1 saisies
#    Lin oléagineux           : 1 saisies
#    Autre culture            : 1 saisies
#    Pechers                  : 1 saisies
#    ENDEMIQUES               : 1 saisies
#    Blé / Tournesol          : 1 saisies
#    Trefle Dactyle           : 1 saisies
#    Campanule                : 1 saisies
#    Clématites               : 1 saisies
#    FEVEROLE d'hiver         : 1 saisies
#    Feverole                 : 1 saisies
#    POMMES DE TERRE          : 1 saisies
#    Lin Hiver                : 1 saisies
#    Pois de printemps        : 1 saisies
#    Pois de Printemps        : 1 saisies
#    Trèfle Incarnat          : 1 saisies
#    autre utilisation        : 1 saisies
#    confflor                 : 1 saisies
#    Poivron                  : 1 saisies
#    Ananas                   : 1 saisies
#    Luzerne depuis 2007      : 1 saisies
#    Jachères                 : 1 saisies
#    Structures agroécologiques: 1 saisies
#    mélange graines 5        : 1 saisies
#    Tournière                : 1 saisies

# %%
# Rend sous forme d'expression régulière une forme du mot plus générique
def to_regex(mot):
    regex_mot = '['+mot[0].upper()+mot[0].lower()+']'+mot[1:] + '|' + mot.upper()
    regex_mot = '(e|é|è)'.join(re.split('e|é|è', regex_mot))
    regex_mot = '(E|É|È)'.join(re.split('E|É|È', regex_mot))
    return regex_mot

# %% [markdown]
# #### Tentative de rechercher les cultures orphelines au sein des noms d'especes existantes

# %%
trouve, toujours_pas, abandonne = {}, {}, []

for nom_saisi, count in noms_saisis_aggreges.items():

    regex_nom_saisi = to_regex(nom_saisi)

    noms_especes_matchantes = df['espece'].loc[df['espece']['libelle_espece_botanique'].str.match(regex_nom_saisi), 'libelle_espece_botanique'].unique()

    if len(noms_especes_matchantes)==0:
        toujours_pas[nom_saisi] = count
    elif len(noms_especes_matchantes)==1:
        trouve[nom_saisi] = noms_especes_matchantes[0]
    else:
        # on regarde les noms d'especes qui ont matché
        print(f'Candidats pour la saisie "{nom_saisi}" : ', noms_especes_matchantes)
        # on attribue à l'espèce dont le nom match parfaitement si il existe
        exact_match = False
        for nom_espece_matchante in noms_especes_matchantes:
            if re.match('^'+regex_nom_saisi+'$', nom_espece_matchante):
                trouve[nom_saisi] = nom_espece_matchante
                exact_match = True
                break # c'est la seule, on a pas deux noms d'espèces égaux à Majuscules près
        if not exact_match:
            # on attribue la culture au nom d'espèce le plus populaire dans la "ferme DEPHY"
            nom_espece_matchante = noms_especes_matchantes[np.argmax([surfaces_occupees.get(nom_espece_matchante, 0) for nom_espece_matchante in noms_especes_matchantes])]
            if nom_espece_matchante in surfaces_occupees:
                trouve[nom_saisi] = nom_espece_matchante
            else:
                # on ne va pas ajouter aléatoirement un des espèces si aucune ne matche complètement et qu'aucune n'est utilisée d'autre part par la "ferme DEPHY"
                abandonne.append(nom_saisi)
print('\n***************************************************************************')
print(f'***** Sur les {len(noms_saisis_aggreges)} noms saisis sans especes associees, on en a retrouvé {len(trouve)}')
print('***************************************************************************')
# Out:
# Candidats pour la saisie "Luzerne" :  ['Luzerne tropicale' 'Luzerne']
# Candidats pour la saisie "Sarrasin" :  ['Sarrasin de Tartarie' 'Sarrasin']
# Candidats pour la saisie "seigle" :  ['Seigle forestier' 'Seigle']
# Candidats pour la saisie "Blé" :  ['Blé dur' 'Blé tendre']
# Candidats pour la saisie "Moutarde" :  ['Moutarde épinard' "Moutarde d'abyssinie" 'Moutarde brune'
#  'Moutarde noire' 'Moutarde blanche']
# Candidats pour la saisie "Pois" :  ['Pois' "Pois d'Angole" 'Pois sabre' 'Pois zye noir' 'Pois doux'
#  'Pois chiche']
# Candidats pour la saisie "Soja" :  ['Soja pérenne' 'Soja']
# Candidats pour la saisie "sainfoin" :  ["Sainfoin d'Espagne" 'Sainfoin']
# Candidats pour la saisie "Ail" :  ['Ail des ours' 'Ail rocambole' 'Ail']
# Candidats pour la saisie "Sainfoin" :  ["Sainfoin d'Espagne" 'Sainfoin']
# Candidats pour la saisie "soja" :  ['Soja pérenne' 'Soja']
# Candidats pour la saisie "Tomate" :  ['Tomate' "Tomate d'amazonie "]
# Candidats pour la saisie "Avoine" :  ['Avoine brésilienne' 'Avoine byzantine' 'Avoine jaunâtre' 'Avoine nue'
#  'Avoine']
# Candidats pour la saisie "Seigle" :  ['Seigle forestier' 'Seigle']
# Candidats pour la saisie "Millet" :  ['Millet perlé' 'Millet commun']
#
# ***************************************************************************
# ***** Sur les 191 noms saisis sans especes associees, on en a retrouvé 55
# ***************************************************************************

# %% [markdown]
# #### Tentative de rechercher les noms d'especes existantes au sein des cultures orphelines

# %%
toujours_toujours_pas = {}

for nom_saisi, count in toujours_pas.items():

    noms_especes_matchantes = []
    for nom_espece in df['espece']['libelle_espece_botanique'].unique():
        regex_nom_espece = to_regex(nom_espece)
        if re.match(regex_nom_espece, nom_saisi) is not None:
            noms_especes_matchantes.append(nom_espece)

    if len(noms_especes_matchantes)==0:
        toujours_toujours_pas[nom_saisi] = count
    elif len(noms_especes_matchantes)==1:
        trouve[nom_saisi] = noms_especes_matchantes[0]
    else:
        # on regarde les noms d'especes qui ont matché
        print(f'\nCandidats pour la saisie "{nom_saisi}" : ', noms_especes_matchantes)
        # on attribue à l'espèce dont le nom match parfaitement si il existe
        exact_match = False
        for nom_espece_matchante in noms_especes_matchantes:
            regex_nom_espece = to_regex(nom_espece_matchante)
            if re.match('^'+regex_nom_espece+'$', nom_saisi):
                trouve[nom_saisi] = nom_espece_matchante
                exact_match = True
                break # c'est la seule, on a pas deux noms d'espèces égaux à Majuscules près
        if not exact_match:
            # on attribue la culture au nom d'espèce le plus populaire dans la "ferme DEPHY"
            nom_espece_matchante = noms_especes_matchantes[np.argmax([surfaces_occupees.get(nom_espece_matchante, 0) for nom_espece_matchante in noms_especes_matchantes])]
            if nom_espece_matchante in surfaces_occupees:
                trouve[nom_saisi] = nom_espece_matchante
            else:
                # on ne va pas ajouter aléatoirement un des espèces si aucune ne matche complètement et qu'aucune n'est utilisée d'autre part par la "ferme DEPHY"
                abandonne.append(nom_saisi)

print('\n***************************************************************************')
print(f'***** Sur les {len(noms_saisis_aggreges)} noms saisis sans especes associees, on en a retrouvé {len(trouve)}')
print('***************************************************************************')
# Out:
# Candidats pour la saisie "FEVEROLES" :  ['Fèverole', 'Fève']
#
# Candidats pour la saisie "FEVEROLE d'hiver" :  ['Fèverole', 'Fève']
#
# ***************************************************************************
# ***** Sur les 191 noms saisis sans especes associees, on en a retrouvé 109
# ***************************************************************************

# %% [markdown]
# ### Inclusion des espèces nouvellement retrouvées au calcul des surfaces respectives

# %%
# On réattribue pour le calcul des surfaces cultivees

surfaces_occupees['INDEFINI'] = 0

for sole_realise in tqdm(soles_avec_culture_indefinie.itertuples(), desc='Parcours des soles avec cultures non linkees a une espece', total=len(soles_avec_culture_indefinie)):
    # zone
    zone = df['zone'].loc[sole_realise.zone_id]
    surface_zone = zone['surface']
    
    # espece
    culture = df['culture'].loc[sole_realise.culture_id]
    if culture['nom'] in trouve:
        nom_espece = trouve[culture['nom']]
    else:
        nom_espece = 'INDEFINI'
    if isinstance(nom_espece, list): # TODO : pour avoir une liste ici, il faut s'atteler à repérer les mélanges d'espèces dans les noms (pas fait)
        for nom_espece_seule in nom_espece:
            proportion_espece = 100/len(nom_espece)
            surfaces_occupees[nom_espece_seule] = surfaces_occupees.get(nom_espece, 0) + surface_zone * proportion_espece / 100
    else:
        surfaces_occupees[nom_espece] = surfaces_occupees.get(nom_espece, 0) + surface_zone

# on trie par especes les plus utilisees
surfaces_occupees = dict(sorted(surfaces_occupees.items(), key=lambda item: item[1], reverse=True))

print()
for nom_espece, surface_occupee in surfaces_occupees.items():
    print(f'L espèce "{nom_espece:^30}" a été cultivée sur {surface_occupee:7.0f} Ha [{(100*surface_occupee / sum(surfaces_occupees.values())):2.1f} %]')
# Out:
# Parcours des soles avec cultures non linkees a une espece: 100%|██████████| 787/787 [00:00<00:00, 16284.66it/s]
# L espèce "          Blé tendre          " a été cultivée sur  189981 Ha [30.4 %]
# L espèce "             Maïs             " a été cultivée sur   85688 Ha [13.7 %]
# L espèce "             Orge             " a été cultivée sur   79615 Ha [12.7 %]
# L espèce "            Colza             " a été cultivée sur   61251 Ha [9.8 %]
# L espèce "           Prairie            " a été cultivée sur   32395 Ha [5.2 %]
# L espèce "          Betterave           " a été cultivée sur   21193 Ha [3.4 %]
# L espèce "          Tournesol           " a été cultivée sur   20132 Ha [3.2 %]
# L espèce "             Pois             " a été cultivée sur   18268 Ha [2.9 %]
# L espèce "           Luzerne            " a été cultivée sur   13551 Ha [2.2 %]
# L espèce "             Soja             " a été cultivée sur   10729 Ha [1.7 %]
# L espèce "           Fèverole           " a été cultivée sur    9170 Ha [1.5 %]
# L espèce "        Pomme de terre        " a été cultivée sur    8447 Ha [1.4 %]
# L espèce "          Triticale           " a été cultivée sur    8424 Ha [1.3 %]
# L espèce "           Blé dur            " a été cultivée sur    7554 Ha [1.2 %]
# L espèce "             Lin              " a été cultivée sur    6789 Ha [1.1 %]
# L espèce "       Espèces diverses       " a été cultivée sur    4547 Ha [0.7 %]
# L espèce "            Avoine            " a été cultivée sur    3447 Ha [0.6 %]
# L espèce "           Lentille           " a été cultivée sur    3139 Ha [0.5 %]
# L espèce "           Chanvre            " a été cultivée sur    2909 Ha [0.5 %]
# L espèce "            Sorgho            " a été cultivée sur    2779 Ha [0.4 %]
# L espèce "      Mélange Fourrager       " a été cultivée sur    2599 Ha [0.4 %]
# L espèce "      Ray-grass d'Italie      " a été cultivée sur    2556 Ha [0.4 %]
# L espèce "        Trèfle violet         " a été cultivée sur    2388 Ha [0.4 %]
# L espèce "            Seigle            " a été cultivée sur    2056 Ha [0.3 %]
# L espèce "           Sarrasin           " a été cultivée sur    1808 Ha [0.3 %]
# L espèce "           Haricot            " a été cultivée sur    1763 Ha [0.3 %]
# L espèce "         Trèfle blanc         " a été cultivée sur    1634 Ha [0.3 %]
# L espèce "      Ray-grass anglais       " a été cultivée sur    1384 Ha [0.2 %]
# L espèce "           Dactyle            " a été cultivée sur    1040 Ha [0.2 %]
# L espèce "      Ray-grass hybride       " a été cultivée sur    1002 Ha [0.2 %]
# L espèce "           Mélange            " a été cultivée sur     953 Ha [0.2 %]
# L espèce "       Trèfle incarnat        " a été cultivée sur     908 Ha [0.1 %]
# L espèce "        Millet commun         " a été cultivée sur     900 Ha [0.1 %]
# L espèce "        Vesce commune         " a été cultivée sur     844 Ha [0.1 %]
# L espèce "             Ail              " a été cultivée sur     801 Ha [0.1 %]
# L espèce "           INDEFINI           " a été cultivée sur     784 Ha [0.1 %]
# L espèce "         Pois chiche          " a été cultivée sur     763 Ha [0.1 %]
# L espèce "           Epeautre           " a été cultivée sur     660 Ha [0.1 %]
# L espèce "           Chicorée           " a été cultivée sur     650 Ha [0.1 %]
# L espèce "        Moutarde brune        " a été cultivée sur     563 Ha [0.1 %]
# L espèce "            Oignon            " a été cultivée sur     545 Ha [0.1 %]
# L espèce "      Oeillette (pavot)       " a été cultivée sur     536 Ha [0.1 %]
# L espèce "           Carotte            " a été cultivée sur     448 Ha [0.1 %]
# L espèce "       Moutarde blanche       " a été cultivée sur     423 Ha [0.1 %]
# L espèce "      Avoine brésilienne      " a été cultivée sur     416 Ha [0.1 %]
# L espèce "        Fétuque élevée        " a été cultivée sur     413 Ha [0.1 %]
# L espèce "     Trèfle d'Alexandrie      " a été cultivée sur     399 Ha [0.1 %]
# L espèce "         Lupin blanc          " a été cultivée sur     392 Ha [0.1 %]
# L espèce "       Fétuque des prés       " a été cultivée sur     287 Ha [0.0 %]
# L espèce "             Chou             " a été cultivée sur     240 Ha [0.0 %]
# L espèce "         Chrysanthème         " a été cultivée sur     200 Ha [0.0 %]
# L espèce "       Fléole des prés        " a été cultivée sur     186 Ha [0.0 %]
# L espèce "           Cameline           " a été cultivée sur     174 Ha [0.0 %]
# L espèce "             Riz              " a été cultivée sur     174 Ha [0.0 %]
# L espèce "           Phacélie           " a été cultivée sur     171 Ha [0.0 %]
# L espèce "           Sainfoin           " a été cultivée sur     159 Ha [0.0 %]
# L espèce "        Autre graminée        " a été cultivée sur     159 Ha [0.0 %]
# L espèce "      Mélange Graminées       " a été cultivée sur     133 Ha [0.0 %]
# L espèce "  Moha ou Millet des oiseaux  " a été cultivée sur     123 Ha [0.0 %]
# L espèce "         Soja pérenne         " a été cultivée sur     116 Ha [0.0 %]
# L espèce "            Lotier            " a été cultivée sur     114 Ha [0.0 %]
# L espèce "       Seigle forestier       " a été cultivée sur     110 Ha [0.0 %]
# L espèce "            Radis             " a été cultivée sur     109 Ha [0.0 %]
# L espèce "     Mélange Floristique      " a été cultivée sur     105 Ha [0.0 %]
# L espèce "      Autre légumineuse       " a été cultivée sur      98 Ha [0.0 %]
# L espèce "           Fraisier           " a été cultivée sur      97 Ha [0.0 %]
# L espèce "           Epinard            " a été cultivée sur      96 Ha [0.0 %]
# L espèce "          Coriandre           " a été cultivée sur      92 Ha [0.0 %]
# L espèce "           Fenugrec           " a été cultivée sur      90 Ha [0.0 %]
# L espèce "         Vesce Velue          " a été cultivée sur      84 Ha [0.0 %]
# L espèce "          Lupin bleu          " a été cultivée sur      83 Ha [0.0 %]
# L espèce "          Artichaut           " a été cultivée sur      82 Ha [0.0 %]
# L espèce "        Trèfle hybride        " a été cultivée sur      75 Ha [0.0 %]
# L espèce "        Mélange chasse        " a été cultivée sur      72 Ha [0.0 %]
# L espèce "           Poireau            " a été cultivée sur      65 Ha [0.0 %]
# L espèce "          Miscanthus          " a été cultivée sur      60 Ha [0.0 %]
# L espèce "            Tomate            " a été cultivée sur      58 Ha [0.0 %]
# L espèce "           Petunia            " a été cultivée sur      50 Ha [0.0 %]
# L espèce "         Calibrachoa          " a été cultivée sur      50 Ha [0.0 %]
# L espèce "         Pelargonium          " a été cultivée sur      50 Ha [0.0 %]
# L espèce "       Autres Potagères       " a été cultivée sur      50 Ha [0.0 %]
# L espèce "       Ray-grass annuel       " a été cultivée sur      49 Ha [0.0 %]
# L espèce "            Laitue            " a été cultivée sur      48 Ha [0.0 %]
# L espèce "        Pâturin commun        " a été cultivée sur      44 Ha [0.0 %]
# L espèce "            Quinoa            " a été cultivée sur      43 Ha [0.0 %]
# L espèce " Gesse Commune ou pois carré  " a été cultivée sur      40 Ha [0.0 %]
# L espèce "           Echalote           " a été cultivée sur      40 Ha [0.0 %]
# L espèce "            Vigne             " a été cultivée sur      40 Ha [0.0 %]
# L espèce "       Trèfle de Perse        " a été cultivée sur      38 Ha [0.0 %]
# L espèce "           Chardon            " a été cultivée sur      38 Ha [0.0 %]
# L espèce "   Engrain (Petit épeautre)   " a été cultivée sur      36 Ha [0.0 %]
# L espèce "          Concombre           " a été cultivée sur      35 Ha [0.0 %]
# L espèce "          Avoine nue          " a été cultivée sur      33 Ha [0.0 %]
# L espèce "           Navette            " a été cultivée sur      33 Ha [0.0 %]
# L espèce "      Trèfle squarrosum       " a été cultivée sur      31 Ha [0.0 %]
# L espèce "       Moutarde épinard       " a été cultivée sur      31 Ha [0.0 %]
# L espèce "      Luzerne tropicale       " a été cultivée sur      29 Ha [0.0 %]
# L espèce "       Lotier corniculé       " a été cultivée sur      28 Ha [0.0 %]
# L espèce "      Trèfle souterrain       " a été cultivée sur      27 Ha [0.0 %]
# L espèce "      Mélange Pollinique      " a été cultivée sur      23 Ha [0.0 %]
# L espèce "           Minette            " a été cultivée sur      23 Ha [0.0 %]
# L espèce "       Trèfle aggloméré       " a été cultivée sur      22 Ha [0.0 %]
# L espèce "       Brome de champs        " a été cultivée sur      19 Ha [0.0 %]
# L espèce "           Pommier            " a été cultivée sur      18 Ha [0.0 %]
# L espèce "            Noyer             " a été cultivée sur      18 Ha [0.0 %]
# L espèce "           Salsifis           " a été cultivée sur      18 Ha [0.0 %]
# L espèce "        Fétuque rouge         " a été cultivée sur      17 Ha [0.0 %]
# L espèce "      Plantain lancéolé       " a été cultivée sur      16 Ha [0.0 %]
# L espèce "         Ail des ours         " a été cultivée sur      16 Ha [0.0 %]
# L espèce "Niébé Cowpea ou Voème Haricot kilomètre" a été cultivée sur      16 Ha [0.0 %]
# L espèce "     Sarrasin de Tartarie     " a été cultivée sur      16 Ha [0.0 %]
# L espèce "            Melon             " a été cultivée sur      15 Ha [0.0 %]
# L espèce "           Fenouil            " a été cultivée sur      14 Ha [0.0 %]
# L espèce "     Autres ornementales      " a été cultivée sur      13 Ha [0.0 %]
# L espèce "            Cardon            " a été cultivée sur      12 Ha [0.0 %]
# L espèce "         Millet perlé         " a été cultivée sur      11 Ha [0.0 %]
# L espèce "            Courge            " a été cultivée sur      11 Ha [0.0 %]
# L espèce "       Avoine byzantine       " a été cultivée sur      11 Ha [0.0 %]
# L espèce "      Trèfle de Micheli       " a été cultivée sur      10 Ha [0.0 %]
# L espèce "             Chia             " a été cultivée sur      10 Ha [0.0 %]
# L espèce "            Navet             " a été cultivée sur       8 Ha [0.0 %]
# L espèce "       Sauge officinale       " a été cultivée sur       8 Ha [0.0 %]
# L espèce "            Nyger             " a été cultivée sur       7 Ha [0.0 %]
# L espèce "            Persil            " a été cultivée sur       7 Ha [0.0 %]
# L espèce "       Vesce du Bengale       " a été cultivée sur       7 Ha [0.0 %]
# L espèce "       Pâturin des prés       " a été cultivée sur       7 Ha [0.0 %]
# L espèce "          Courgette           " a été cultivée sur       7 Ha [0.0 %]
# L espèce "         Framboisier          " a été cultivée sur       6 Ha [0.0 %]
# L espèce "          Aubergine           " a été cultivée sur       6 Ha [0.0 %]
# L espèce "            Lablab            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Potiron            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Asperge            " a été cultivée sur       6 Ha [0.0 %]
# L espèce "             Anis             " a été cultivée sur       6 Ha [0.0 %]
# L espèce "           Carthame           " a été cultivée sur       5 Ha [0.0 %]
# L espèce "            Panais            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "           Oseille            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "            Céleri            " a été cultivée sur       5 Ha [0.0 %]
# L espèce "        Canne à sucre         " a été cultivée sur       4 Ha [0.0 %]
# L espèce "         Brome dressé         " a été cultivée sur       4 Ha [0.0 %]
# L espèce "             Fève             " a été cultivée sur       4 Ha [0.0 %]
# L espèce "       Fléole bulbeuse        " a été cultivée sur       4 Ha [0.0 %]
# L espèce "            Aneth             " a été cultivée sur       4 Ha [0.0 %]
# L espèce "           Prunier            " a été cultivée sur       4 Ha [0.0 %]
# L espèce "           Lavande            " a été cultivée sur       4 Ha [0.0 %]
# L espèce "             Thym             " a été cultivée sur       4 Ha [0.0 %]
# L espèce "       Trèfle vésiculé        " a été cultivée sur       4 Ha [0.0 %]
# L espèce "      Vesce de Narbonne       " a été cultivée sur       3 Ha [0.0 %]
# L espèce "           Peuplier           " a été cultivée sur       3 Ha [0.0 %]
# L espèce "            Saule             " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Mélisse            " a été cultivée sur       2 Ha [0.0 %]
# L espèce "        Pâturin annuel        " a été cultivée sur       2 Ha [0.0 %]
# L espèce "          Angélique           " a été cultivée sur       2 Ha [0.0 %]
# L espèce "            Aulne             " a été cultivée sur       2 Ha [0.0 %]
# L espèce "     Matricaire camomille     " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Cerisier           " a été cultivée sur       2 Ha [0.0 %]
# L espèce "         Trèfle strié         " a été cultivée sur       2 Ha [0.0 %]
# L espèce "           Poirier            " a été cultivée sur       2 Ha [0.0 %]
# L espèce "      Sainfoin d'Espagne      " a été cultivée sur       1 Ha [0.0 %]
# L espèce "          Abricotier          " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Pêcher            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Sapin             " a été cultivée sur       1 Ha [0.0 %]
# L espèce "          Bourrache           " a été cultivée sur       1 Ha [0.0 %]
# L espèce "        Lagerstroemia         " a été cultivée sur       1 Ha [0.0 %]
# L espèce "           Romarin            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "            Ananas            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "       Plantain majeur        " a été cultivée sur       1 Ha [0.0 %]
# L espèce "           Statice            " a été cultivée sur       1 Ha [0.0 %]
# L espèce "     Lentille fourragère      " a été cultivée sur       1 Ha [0.0 %]
# L espèce "  Panic érigé (switch grass)  " a été cultivée sur       1 Ha [0.0 %]
# L espèce "         Patate douce         " a été cultivée sur       1 Ha [0.0 %]
# L espèce "        Trèfle hérissé        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Litchi            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Poivrier noir         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Mâche             " a été cultivée sur       0 Ha [0.0 %]
# L espèce " Dauphinelle à grandes fleurs " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Crotalaria          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Vanille            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Cyclamen           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Viola             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Piment Poivron        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Pastèque           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Brachiaria ruziziensis     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Souci             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Igname            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Fruit de la passion      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Muscari            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Curcuma            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Gingembre           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Lisianthus          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Mélilot officinal       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Chou chinois         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Prunier de Cythère      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Roquette           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Alchémille          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Bananier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Gombo             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Giroflée ravenelle      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Gerbera            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Renoncule           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "    Ciboule ou Oignon pays    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Pois sabre          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "      Rosier multiflore       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Rosier            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Célosie            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Muflier            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Pois doux           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Basilic            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Papayer            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Cacaoyer commun        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "Hibiscus sabdariffa ou Groseille péyi" a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Corossol           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Figuier            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Avocatier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Manguier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Arachide           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Moutarde d'abyssinie     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "    Vipérine faux plantain    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Centaurée bleuet       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Fétuque ovine         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Centaurée           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Reine marguerite       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Tanaisie = chrysanthème    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Alliaire           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "   Chayotte = Christophine    " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Grenadier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Attier Pomme Canelle     " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Campanule           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Anémone            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "     Pavot de Californie      " a été cultivée sur       0 Ha [0.0 %]
# L espèce "  Pomme Liane ou Grenadille   " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Primevère           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Pensée            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Arbousier commun       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Myrthe ou myrte        " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Pittosporum          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Cistus            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Camélia            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Choisya            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Arbre à pain         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Groseiller          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Menthe            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Estragon           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Ciboulette          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Heuchère           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "       Géranium vivaces       " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Rose d'Inde          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Myosotis           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Noisetier           " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Chêne             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Hêtre             " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Viorne            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "         Châtaignier          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Charme            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Sureau            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Cornus            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Potentille          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "        Œillet d'Inde         " a été cultivée sur       0 Ha [0.0 %]
# L espèce "          Immortelle          " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Jasmin            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "            Manioc            " a été cultivée sur       0 Ha [0.0 %]
# L espèce "           Dachine            " a été cultivée sur       0 Ha [0.0 %]

# %% [markdown]
# ### Graphique mis à jour

# %%
# Diagramme camembert
plt.figure(figsize=(8, 8)) # Taille du diagramme
plt.pie(surfaces_occupees.values(), labels=surfaces_occupees.keys(), autopct='%1.1f%%', startangle=140)

plt.title('Répartition des surfaces cultivées ("saisies réalisé")dans Agrosyst')
plt.axis('equal') # Permet d'avoir un diagramme circulaire plutôt qu'elliptique
plt.show()

# %% [markdown]
# # Pour aller un peu plus loin

# %% [markdown]
# ###  => 4 métacatégories de cultures non liées à des espèces expliquant beaucoup de saisies restantes

# %%
print(f"Les {len(toujours_toujours_pas)} cultures toujours pas captées au sein d'un nom d'espèce botanique sont :")
dict(sorted(toujours_toujours_pas.items(), key=lambda item: item[1], reverse=True))
# Out:
# Les 82 cultures toujours pas captées au sein d'un nom d'espèce botanique sont :
# {'Jachère': 84,
#  'Jachère > 5 ans': 47,
#  'Jachère de 6 ans ou plus': 39,
#  'Vide sanitaire': 24,
#  'Plante de service': 10,
#  'plante de service': 10,
#  'Méteil de printemps': 9,
#  'MAIS GRAIN': 9,
#  'CROTALAIRE': 6,
#  'Eleusine': 6,
#  'Alysse': 6,
#  'Blette': 6,
#  'OP': 6,
#  'Jachère et gel melifere': 6,
#  'Jachère 6 ans ou plus ou temporaire': 5,
#  'Espèce diverse': 5,
#  'Friche': 5,
#  'Jachère floristique de 5 ans ou moins': 4,
#  'Haie endémique': 4,
#  'PT (PT)': 4,
#  'MAIS FOURRAGE': 4,
#  'SONGE GRISE': 4,
#  'Jachère permanente': 4,
#  'calebasse': 4,
#  'PT': 3,
#  'Jachère en légumineuses': 3,
#  'Jachère en graminées': 3,
#  'Salade': 3,
#  'Culture dérobée': 2,
#  'RGI + Trefle': 2,
#  "ray grass d'italie": 2,
#  'Citronnelle': 2,
#  'jachère': 2,
#  'RGA': 2,
#  'crotalaire': 2,
#  'DAE Maïs': 2,
#  'Précédent fictif': 2,
#  'zone enherbée': 2,
#  'Vétiver': 2,
#  'autres cépages': 2,
#  'Trèfle pur': 2,
#  'Friche agricole': 2,
#  'Citrouille péi et butternut': 2,
#  "Blé d'oeillette": 2,
#  'Parcours': 2,
#  'Méteil': 2,
#  'PDS AROMATES': 2,
#  'Culture légumière : melons / céleris / légumes': 2,
#  'Trèfle semence': 2,
#  'Plantes en pot de diversification de printemps': 1,
#  'JACHERE  ': 1,
#  'RG-Trèfle': 1,
#  'Songe 1 divers': 1,
#  'Gamme arbuste - Perovskia + Exochorda': 1,
#  'Conteneur': 1,
#  'Trèfle (semence)': 1,
#  'Gel': 1,
#  'Verger pour Greffons': 1,
#  'VETIVER': 1,
#  'Citrouille': 1,
#  'méteil': 1,
#  'Citrouille péi': 1,
#  'Escourgeon': 1,
#  'Trèfle alexandrie semences': 1,
#  'pleine terre Bruyères': 1,
#  'Jachère depuis 2010': 1,
#  'mais fourrager': 1,
#  'Petits Fruitiers': 1,
#  'Autre culture': 1,
#  'Pechers': 1,
#  'ENDEMIQUES': 1,
#  'Blé / Tournesol': 1,
#  'Trefle Dactyle': 1,
#  'Clématites': 1,
#  'POMMES DE TERRE': 1,
#  'Trèfle Incarnat': 1,
#  'autre utilisation': 1,
#  'confflor': 1,
#  'Poivron': 1,
#  'Jachères': 1,
#  'Structures agroécologiques': 1,
#  'Tournière': 1}

# %%
familles_culture_orpheline = {
    'Jachère': [r".*[Jj]ach(e|é|è)res?|.*JACH(E|É|È)RES?",], 
    'Vide sanitaire': [r"[Vv]ides?( |_|-)[Ss]anitaires?|VIDES?( |_|-)SANITAIRES?",], 
    'Plante de service': [r"[Pp]lante de service",], 
    'Friche': [r".*[Ff]riches?|.*FRICHES?",], 
    # 'Prairie temporaire': [r"[Pp]rairies?( |_|-)[Tt]emporaires?|PRAIRIES?( |_|-)TEMPORAIRES?",], 
    # 'Prairie permanente': [r"[Pp]rairies?( |_|-)[Pp]ermanentes?|PRAIRIES?( |_|-)PERMANENTES?",], 
    # 'Espèces diverses': [r"Espèces? diverses?",], 
} # etc

def classif_culture_sans_reference(nom_saisi):
    
    for famille, textes_possibles in familles_culture_orpheline.items():
        for texte_possible in textes_possibles:
            correspondance = re.match(texte_possible, nom_saisi)
            if correspondance:
                return famille
    return None


retrouvees = {}
combien_retrouvees = 0
toujours_toujours_toujours_pas = {}

for nom_saisi, count in toujours_toujours_pas.items():
    famille_trouvee = classif_culture_sans_reference(nom_saisi)
    if famille_trouvee is None:
        toujours_toujours_toujours_pas[nom_saisi] = count
    else:
        retrouvees[nom_saisi] = famille_trouvee
        combien_retrouvees += count

print(f'Retrouvées sous les familles proposées [{len(retrouvees)} noms ({combien_retrouvees} saisies)]:')
for culture_orpheline, famille in sorted(retrouvees.items(), key=lambda item: item[1], reverse=True):
    print(f'   {culture_orpheline} --> {famille}')
print()
print(f'Reste [{len(toujours_toujours_toujours_pas)} noms ({sum(toujours_toujours_toujours_pas.values())} saisies)]:')
for culture_orpheline, nombre in sorted(toujours_toujours_toujours_pas.items(), key=lambda item: item[1], reverse=True):
    print(f'   {culture_orpheline}: {nombre} saisies')
# Out:
# Retrouvées sous les familles proposées [18 noms (251 saisies)]:
#    Vide sanitaire --> Vide sanitaire
#    Plante de service --> Plante de service
#    plante de service --> Plante de service
#    JACHERE   --> Jachère
#    Jachère --> Jachère
#    Jachère 6 ans ou plus ou temporaire --> Jachère
#    Jachère floristique de 5 ans ou moins --> Jachère
#    jachère --> Jachère
#    Jachère de 6 ans ou plus --> Jachère
#    Jachère > 5 ans --> Jachère
#    Jachère en légumineuses --> Jachère
#    Jachère en graminées --> Jachère
#    Jachère et gel melifere --> Jachère
#    Jachère permanente --> Jachère
#    Jachère depuis 2010 --> Jachère
#    Jachères --> Jachère
#    Friche --> Friche
#    Friche agricole --> Friche
#
# Reste [64 noms (147 saisies)]:
#    Méteil de printemps: 9 saisies
#    MAIS GRAIN: 9 saisies
#    CROTALAIRE: 6 saisies
#    Eleusine: 6 saisies
#    Alysse: 6 saisies
#    Blette: 6 saisies
#    OP: 6 saisies
#    Espèce diverse: 5 saisies
#    Haie endémique: 4 saisies
#    PT (PT): 4 saisies
#    MAIS FOURRAGE: 4 saisies
#    SONGE GRISE: 4 saisies
#    calebasse: 4 saisies
#    PT: 3 saisies
#    Salade: 3 saisies
#    Culture dérobée: 2 saisies
#    RGI + Trefle: 2 saisies
#    ray grass d'italie: 2 saisies
#    Citronnelle: 2 saisies
#    RGA: 2 saisies
#    crotalaire: 2 saisies
#    DAE Maïs: 2 saisies
#    Précédent fictif: 2 saisies
#    zone enherbée: 2 saisies
#    Vétiver: 2 saisies
#    autres cépages: 2 saisies
#    Trèfle pur: 2 saisies
#    Citrouille péi et butternut: 2 saisies
#    Blé d'oeillette: 2 saisies
#    Parcours: 2 saisies
#    Méteil: 2 saisies
#    PDS AROMATES: 2 saisies
#    Culture légumière : melons / céleris / légumes: 2 saisies
#    Trèfle semence: 2 saisies
#    Plantes en pot de diversification de printemps: 1 saisies
#    RG-Trèfle: 1 saisies
#    Songe 1 divers: 1 saisies
#    Gamme arbuste - Perovskia + Exochorda: 1 saisies
#    Conteneur: 1 saisies
#    Trèfle (semence): 1 saisies
#    Gel: 1 saisies
#    Verger pour Greffons: 1 saisies
#    VETIVER: 1 saisies
#    Citrouille: 1 saisies
#    méteil: 1 saisies
#    Citrouille péi: 1 saisies
#    Escourgeon: 1 saisies
#    Trèfle alexandrie semences: 1 saisies
#    pleine terre Bruyères: 1 saisies
#    mais fourrager: 1 saisies
#    Petits Fruitiers: 1 saisies
#    Autre culture: 1 saisies
#    Pechers: 1 saisies
#    ENDEMIQUES: 1 saisies
#    Blé / Tournesol: 1 saisies
#    Trefle Dactyle: 1 saisies
#    Clématites: 1 saisies
#    POMMES DE TERRE: 1 saisies
#    Trèfle Incarnat: 1 saisies
#    autre utilisation: 1 saisies
#    confflor: 1 saisies
#    Poivron: 1 saisies
#    Structures agroécologiques: 1 saisies
#    Tournière: 1 saisies

# %% [markdown]
# On voit donc que la plupart des saisies de culture où l'agent n'a pas renseigné d'espèce(s) associée(s), on peut tout de même retrouver un nom d'espèce parmi les noms d'espèces botanique existants; et dans les cas où on ne peut toujours pas, on a pu classer la majeure partie des saisies dans un nombre de catégories restreint (4).
