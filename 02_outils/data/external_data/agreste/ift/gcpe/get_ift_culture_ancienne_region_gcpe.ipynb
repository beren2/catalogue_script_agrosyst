# %% [markdown]
# #### Import des librairies

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
path_file = './'

ENTREPOT_PATH = '~/Bureau/utils/data/'
df = {}

# %%
# campagne : campagne de l'enquête PK
# starting_line : ligne de départ pour la lecture du fichier excel
# values_out_regions : lignes à exclure de la lecture du fichier excel (pour la colonne Région)
# region_column : nom de la colonne où est stockée la région


STUDIES = [
    {
        'campagne' : 2017,
        'starting_line' : 0,
        'values_out_regions' : ['Demi-intervalle de confiance'], 
        'region_column' : 'Région'
    },
    {
        'campagne' : 2021,
        'starting_line' : 1,
        'values_out_regions' : [], 
        'region_column' : ' '
    }
]

# %%
def load_ift_culture_ancienne_region_gcpe(campagne, start_line=1, values_out_regions=[], region_column='Région'):
    """
        Ouvre le fichier brut des informations Agreste
        et le transforme en un DataFrame pandas avec les colonnes attendues pour la suite :
        - 
        
    """

    file_name = 'ift_culture_ancienne_region_gcpe_brut_' + str(campagne)
    df['ift_culture_ancienne_region_gcpe'] = pd.read_csv(path_file+file_name+'.csv')


    # quelques retructurations sont nécessaires pour faciliter le traitement du fichier
    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].iloc[start_line:]
    df['ift_culture_ancienne_region_gcpe'].columns = df['ift_culture_ancienne_region_gcpe'].iloc[0].values
    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].iloc[1:-3]
    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].rename(columns={
        region_column : 'nom_ancienne_region'
    }).set_index('nom_ancienne_region')

    # on exclue les lignes dont la région vaut les valeurs qu'on veux exclure
    for value in values_out_regions:
        df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'][
            df['ift_culture_ancienne_region_gcpe'].index != value
        ]

    # Convertir les colonnes en float
    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].replace(
        to_replace='ns', value=np.nan
    )

    df['ift_culture_ancienne_region_gcpe']  = df['ift_culture_ancienne_region_gcpe'].applymap(
        lambda x: str(x).replace(",", ".") if pd.notna(x) else x
    )

    for col in df['ift_culture_ancienne_region_gcpe'].columns:
        df['ift_culture_ancienne_region_gcpe'][col] = pd.to_numeric(
            df['ift_culture_ancienne_region_gcpe'][col], errors='coerce'
        )

    # petite correction pour Centre val de loire.
    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].reset_index()
    df['ift_culture_ancienne_region_gcpe'].loc[
        df['ift_culture_ancienne_region_gcpe']['nom_ancienne_region'] == 'Centre' , 'nom_ancienne_region'
    ] = 'Centre-Val de Loire'

    df['ift_culture_ancienne_region_gcpe'] = df['ift_culture_ancienne_region_gcpe'].set_index('nom_ancienne_region')

    df['ift_culture_ancienne_region_gcpe'].to_csv('ift_culture_ancienne_region_gcpe_'+str(campagne)+'.csv', index=True)

# %%
df['ift_culture_ancienne_region_gcpe']
# Out:
#                             Blé tendre  Blé dur  Orge  Triticale  Colza  \
# nom_ancienne_region
# Alsace                             3.4      NaN   NaN        NaN    NaN
# Aquitaine                          NaN      NaN   NaN        1.9    NaN
# Auvergne                           3.5      NaN   NaN        2.3    5.8
# Basse-Normandie                    5.1      NaN   4.6        3.5    6.7
# Bourgogne                          4.3      NaN   4.9        2.4    6.9
# Bretagne                           4.6      NaN   4.4        3.7    3.9
# Centre                             5.3      5.5   4.7        2.9    6.8
# Champagne-Ardenne                  5.7      NaN   4.0        3.0    6.4
# Franche-Comté                      4.4      NaN   4.3        NaN    6.2
# Guadeloupe                         NaN      NaN   NaN        NaN    NaN
# Haute-Normandie                    6.6      NaN   5.3        NaN    6.6
# Ile-de-France                      6.4      NaN   4.7        NaN    6.5
# La Réunion                         NaN      NaN   NaN        NaN    NaN
# Languedoc-Roussillon               NaN      3.2   NaN        0.5    NaN
# Limousin                           NaN      NaN   NaN        2.4    NaN
# Lorraine                           4.5      NaN   3.7        2.5    5.9
# Martinique                         NaN      NaN   NaN        NaN    NaN
# Midi-Pyrénées                      3.3      4.3   2.8        2.2    5.7
# Nord-Pas-de-Calais                 6.3      NaN   4.7        NaN    5.1
# Pays de la Loire                   4.9      4.3   4.3        3.3    5.7
# Picardie                           5.8      NaN   4.9        NaN    6.2
# Poitou-Charentes                   4.9      4.8   4.5        2.8    7.5
# Provence-Alpes-Côte d'Azur         NaN      2.4   NaN        NaN    NaN
# Rhône-Alpes                        3.2      3.0   2.8        2.0    4.5
# Ensemble                           5.1      4.2   4.4        2.6    6.4
#
#                             Tournesol  Pois protéagineux  Maïs fourrage  \
# nom_ancienne_region
# Alsace                            NaN                NaN            NaN
# Aquitaine                         3.1                NaN            2.2
# Auvergne                          2.5                NaN            2.1
# Basse-Normandie                   NaN                5.6            2.5
# Bourgogne                         2.5                4.0            2.3
# Bretagne                          NaN                NaN            2.5
# Centre                            3.0                5.5            2.6
# Champagne-Ardenne                 NaN                4.1            2.8
# Franche-Comté                     NaN                NaN            NaN
# Guadeloupe                        NaN                NaN            NaN
# Haute-Normandie                   NaN                5.5            2.4
# Ile-de-France                     NaN                5.4            NaN
# La Réunion                        NaN                NaN            NaN
# Languedoc-Roussillon              2.5                4.3            NaN
# Limousin                          NaN                NaN            1.8
# Lorraine                          2.6                2.8            2.3
# Martinique                        NaN                NaN            NaN
# Midi-Pyrénées                     2.6                4.3            2.0
# Nord-Pas-de-Calais                NaN                4.7            2.5
# Pays de la Loire                  2.5                4.6            2.4
# Picardie                          NaN                5.3            2.3
# Poitou-Charentes                  2.6                4.6            2.3
# Provence-Alpes-Côte d'Azur        NaN                NaN            NaN
# Rhône-Alpes                       2.7                NaN            2.4
# Ensemble                          2.7                4.6            2.4
#
#                             Maïs grain  Betterave sucrière  Pomme de terre  \
# nom_ancienne_region
# Alsace                             2.9                 NaN             NaN
# Aquitaine                          2.8                 NaN             NaN
# Auvergne                           3.3                 NaN             NaN
# Basse-Normandie                    NaN                 5.1             NaN
# Bourgogne                          2.9                 NaN             NaN
# Bretagne                           2.5                 NaN            17.5
# Centre                             3.2                 6.1            12.5
# Champagne-Ardenne                  3.0                 6.4            18.8
# Franche-Comté                      NaN                 NaN             NaN
# Guadeloupe                         NaN                 NaN             NaN
# Haute-Normandie                    NaN                 5.2            17.4
# Ile-de-France                      2.9                 5.7            13.1
# La Réunion                         NaN                 NaN             NaN
# Languedoc-Roussillon               NaN                 NaN             NaN
# Limousin                           NaN                 NaN             NaN
# Lorraine                           2.9                 NaN             NaN
# Martinique                         NaN                 NaN             NaN
# Midi-Pyrénées                      2.6                 NaN             NaN
# Nord-Pas-de-Calais                 2.3                 4.7            16.5
# Pays de la Loire                   2.7                 NaN             NaN
# Picardie                           2.5                 5.2            16.7
# Poitou-Charentes                   2.9                 NaN             NaN
# Provence-Alpes-Côte d'Azur         NaN                 NaN             NaN
# Rhône-Alpes                        3.0                 NaN             NaN
# Ensemble                           2.8                 5.5            16.5
#
#                             Canne à sucre  Féverole  Soja  Lin fibre  \
# nom_ancienne_region
# Alsace                                NaN       NaN   NaN        NaN
# Aquitaine                             NaN       1.1   1.7        NaN
# Auvergne                              NaN       NaN   NaN        NaN
# Basse-Normandie                       NaN       5.5   NaN        NaN
# Bourgogne                             NaN       NaN   2.1        NaN
# Bretagne                              NaN       3.4   NaN        NaN
# Centre                                NaN       3.0   NaN        NaN
# Champagne-Ardenne                     NaN       4.1   NaN        NaN
# Franche-Comté                         NaN       NaN   2.1        NaN
# Guadeloupe                            1.7       NaN   NaN        NaN
# Haute-Normandie                       NaN       4.8   NaN        5.5
# Ile-de-France                         NaN       4.1   NaN        NaN
# La Réunion                            3.2       NaN   NaN        NaN
# Languedoc-Roussillon                  NaN       NaN   NaN        NaN
# Limousin                              NaN       NaN   NaN        NaN
# Lorraine                              NaN       NaN   NaN        NaN
# Martinique                            3.2       NaN   NaN        NaN
# Midi-Pyrénées                         NaN       1.8   1.5        NaN
# Nord-Pas-de-Calais                    NaN       4.7   NaN        4.5
# Pays de la Loire                      NaN       2.5   NaN        NaN
# Picardie                              NaN       4.0   NaN        4.6
# Poitou-Charentes                      NaN       2.4   NaN        NaN
# Provence-Alpes-Côte d'Azur            NaN       NaN   NaN        NaN
# Rhône-Alpes                           NaN       NaN   2.1        NaN
# Ensemble                              2.7       3.2   1.8        5.1
#
#                             Lin Oléagineux
# nom_ancienne_region
# Alsace                                 NaN
# Aquitaine                              NaN
# Auvergne                               NaN
# Basse-Normandie                        NaN
# Bourgogne                              4.0
# Bretagne                               NaN
# Centre                                 5.0
# Champagne-Ardenne                      NaN
# Franche-Comté                          NaN
# Guadeloupe                             NaN
# Haute-Normandie                        NaN
# Ile-de-France                          NaN
# La Réunion                             NaN
# Languedoc-Roussillon                   NaN
# Limousin                               NaN
# Lorraine                               3.7
# Martinique                             NaN
# Midi-Pyrénées                          2.1
# Nord-Pas-de-Calais                     NaN
# Pays de la Loire                       4.2
# Picardie                               NaN
# Poitou-Charentes                       3.5
# Provence-Alpes-Côte d'Azur             NaN
# Rhône-Alpes                            NaN
# Ensemble                               3.8

# %%
# on applique la fonction pour obtenir le fichier final sur toutes les campagnes étudiées
for study in STUDIES :
    load_ift_culture_ancienne_region_gcpe(
        study['campagne'],
        start_line=study['starting_line'],
        values_out_regions=study['values_out_regions'], 
        region_column=study['region_column']
    )
# Out:
# /tmp/ipykernel_170237/1555280569.py:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['ift_culture_ancienne_region_gcpe']  = df['ift_culture_ancienne_region_gcpe'].applymap(
# /tmp/ipykernel_170237/1555280569.py:32: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df['ift_culture_ancienne_region_gcpe']  = df['ift_culture_ancienne_region_gcpe'].applymap(

# %%
df['ift_culture_ancienne_region_gcpe']
# Out:
#                             Blé tendre  Blé dur  Orge  Triticale  Colza  \
# nom_ancienne_region
# Alsace                             3.4      NaN   NaN        NaN    NaN
# Aquitaine                          NaN      NaN   NaN        1.9    NaN
# Auvergne                           3.5      NaN   NaN        2.3    5.8
# Basse-Normandie                    5.1      NaN   4.6        3.5    6.7
# Bourgogne                          4.3      NaN   4.9        2.4    6.9
# Bretagne                           4.6      NaN   4.4        3.7    3.9
# Centre                             5.3      5.5   4.7        2.9    6.8
# Champagne-Ardenne                  5.7      NaN   4.0        3.0    6.4
# Franche-Comté                      4.4      NaN   4.3        NaN    6.2
# Guadeloupe                         NaN      NaN   NaN        NaN    NaN
# Haute-Normandie                    6.6      NaN   5.3        NaN    6.6
# Ile-de-France                      6.4      NaN   4.7        NaN    6.5
# La Réunion                         NaN      NaN   NaN        NaN    NaN
# Languedoc-Roussillon               NaN      3.2   NaN        0.5    NaN
# Limousin                           NaN      NaN   NaN        2.4    NaN
# Lorraine                           4.5      NaN   3.7        2.5    5.9
# Martinique                         NaN      NaN   NaN        NaN    NaN
# Midi-Pyrénées                      3.3      4.3   2.8        2.2    5.7
# Nord-Pas-de-Calais                 6.3      NaN   4.7        NaN    5.1
# Pays de la Loire                   4.9      4.3   4.3        3.3    5.7
# Picardie                           5.8      NaN   4.9        NaN    6.2
# Poitou-Charentes                   4.9      4.8   4.5        2.8    7.5
# Provence-Alpes-Côte d'Azur         NaN      2.4   NaN        NaN    NaN
# Rhône-Alpes                        3.2      3.0   2.8        2.0    4.5
# Ensemble                           5.1      4.2   4.4        2.6    6.4
#
#                             Tournesol  Pois protéagineux  Maïs fourrage  \
# nom_ancienne_region
# Alsace                            NaN                NaN            NaN
# Aquitaine                         3.1                NaN            2.2
# Auvergne                          2.5                NaN            2.1
# Basse-Normandie                   NaN                5.6            2.5
# Bourgogne                         2.5                4.0            2.3
# Bretagne                          NaN                NaN            2.5
# Centre                            3.0                5.5            2.6
# Champagne-Ardenne                 NaN                4.1            2.8
# Franche-Comté                     NaN                NaN            NaN
# Guadeloupe                        NaN                NaN            NaN
# Haute-Normandie                   NaN                5.5            2.4
# Ile-de-France                     NaN                5.4            NaN
# La Réunion                        NaN                NaN            NaN
# Languedoc-Roussillon              2.5                4.3            NaN
# Limousin                          NaN                NaN            1.8
# Lorraine                          2.6                2.8            2.3
# Martinique                        NaN                NaN            NaN
# Midi-Pyrénées                     2.6                4.3            2.0
# Nord-Pas-de-Calais                NaN                4.7            2.5
# Pays de la Loire                  2.5                4.6            2.4
# Picardie                          NaN                5.3            2.3
# Poitou-Charentes                  2.6                4.6            2.3
# Provence-Alpes-Côte d'Azur        NaN                NaN            NaN
# Rhône-Alpes                       2.7                NaN            2.4
# Ensemble                          2.7                4.6            2.4
#
#                             Maïs grain  Betterave sucrière  Pomme de terre  \
# nom_ancienne_region
# Alsace                             2.9                 NaN             NaN
# Aquitaine                          2.8                 NaN             NaN
# Auvergne                           3.3                 NaN             NaN
# Basse-Normandie                    NaN                 5.1             NaN
# Bourgogne                          2.9                 NaN             NaN
# Bretagne                           2.5                 NaN            17.5
# Centre                             3.2                 6.1            12.5
# Champagne-Ardenne                  3.0                 6.4            18.8
# Franche-Comté                      NaN                 NaN             NaN
# Guadeloupe                         NaN                 NaN             NaN
# Haute-Normandie                    NaN                 5.2            17.4
# Ile-de-France                      2.9                 5.7            13.1
# La Réunion                         NaN                 NaN             NaN
# Languedoc-Roussillon               NaN                 NaN             NaN
# Limousin                           NaN                 NaN             NaN
# Lorraine                           2.9                 NaN             NaN
# Martinique                         NaN                 NaN             NaN
# Midi-Pyrénées                      2.6                 NaN             NaN
# Nord-Pas-de-Calais                 2.3                 4.7            16.5
# Pays de la Loire                   2.7                 NaN             NaN
# Picardie                           2.5                 5.2            16.7
# Poitou-Charentes                   2.9                 NaN             NaN
# Provence-Alpes-Côte d'Azur         NaN                 NaN             NaN
# Rhône-Alpes                        3.0                 NaN             NaN
# Ensemble                           2.8                 5.5            16.5
#
#                             Canne à sucre  Féverole  Soja  Lin fibre  \
# nom_ancienne_region
# Alsace                                NaN       NaN   NaN        NaN
# Aquitaine                             NaN       1.1   1.7        NaN
# Auvergne                              NaN       NaN   NaN        NaN
# Basse-Normandie                       NaN       5.5   NaN        NaN
# Bourgogne                             NaN       NaN   2.1        NaN
# Bretagne                              NaN       3.4   NaN        NaN
# Centre                                NaN       3.0   NaN        NaN
# Champagne-Ardenne                     NaN       4.1   NaN        NaN
# Franche-Comté                         NaN       NaN   2.1        NaN
# Guadeloupe                            1.7       NaN   NaN        NaN
# Haute-Normandie                       NaN       4.8   NaN        5.5
# Ile-de-France                         NaN       4.1   NaN        NaN
# La Réunion                            3.2       NaN   NaN        NaN
# Languedoc-Roussillon                  NaN       NaN   NaN        NaN
# Limousin                              NaN       NaN   NaN        NaN
# Lorraine                              NaN       NaN   NaN        NaN
# Martinique                            3.2       NaN   NaN        NaN
# Midi-Pyrénées                         NaN       1.8   1.5        NaN
# Nord-Pas-de-Calais                    NaN       4.7   NaN        4.5
# Pays de la Loire                      NaN       2.5   NaN        NaN
# Picardie                              NaN       4.0   NaN        4.6
# Poitou-Charentes                      NaN       2.4   NaN        NaN
# Provence-Alpes-Côte d'Azur            NaN       NaN   NaN        NaN
# Rhône-Alpes                           NaN       NaN   2.1        NaN
# Ensemble                              2.7       3.2   1.8        5.1
#
#                             Lin Oléagineux
# nom_ancienne_region
# Alsace                                 NaN
# Aquitaine                              NaN
# Auvergne                               NaN
# Basse-Normandie                        NaN
# Bourgogne                              4.0
# Bretagne                               NaN
# Centre                                 5.0
# Champagne-Ardenne                      NaN
# Franche-Comté                          NaN
# Guadeloupe                             NaN
# Haute-Normandie                        NaN
# Ile-de-France                          NaN
# La Réunion                             NaN
# Languedoc-Roussillon                   NaN
# Limousin                               NaN
# Lorraine                               3.7
# Martinique                             NaN
# Midi-Pyrénées                          2.1
# Nord-Pas-de-Calais                     NaN
# Pays de la Loire                       4.2
# Picardie                               NaN
# Poitou-Charentes                       3.5
# Provence-Alpes-Côte d'Azur             NaN
# Rhône-Alpes                            NaN
# Ensemble                               3.8
