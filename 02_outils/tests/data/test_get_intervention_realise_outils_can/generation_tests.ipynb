# %%
import pandas as pd
from tqdm import tqdm
from itables import show as table_show

# %%
ENTREPOT_PATH = '~/Bureau/utils/data/'
METEO_PATH = '~/Bureau/utils/data/meteo/'
SPATIAL_PATH = './data/spatial/'

# %%
#obtention des donnnées de la CAN :
directory = '~/Bureau/Exports/20240524/non_anonyme/'
file = 'AGS_20240524_exports_performance_realise_echelle_intervention.csv'
df_can = pd.read_csv(directory+file, sep='@')
# Out:
# /tmp/ipykernel_77976/3676667437.py:4: DtypeWarning: Columns (6,26,27,28,29,145,264) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_can = pd.read_csv(directory+file, sep='@')

# %%
df_can.columns[0:50]
# Out:
# Index(['performance_id', 'date_calcul', 'domaine_nom', 'domaine_id',
#        'domaine_campagne', 'domaine_type', 'departement', 'dispositif_id',
#        'dispositif_type', 'nom_reseau_it', 'nom_reseau_ir', 'sdc_filiere',
#        'sdc_nom', 'sdc_id', 'parcelle_nom', 'parcelle_id', 'zone_nom',
#        'zone_id', 'sdc_code_dephy', 'sdc_type_agriculture', 'sdc_valide',
#        'culture_nom', 'culture_id', 'culture_rang', 'culture_especes_edi',
#        'variete_nom', 'precedent_nom', 'precedent_id', 'phase', 'phase_id',
#        'intervention_nom', 'intervention_id', 'date_debut', 'date_fin',
#        'interventions_actions', 'interventions_intrants',
#        'interventions_cibles_trait', 'approche_de_calcul',
#        'ift_histo_chimique_tot', 'ift_histo_chim_tot_hts', 'ift_histo_h',
#        'ift_histo_f', 'ift_histo_i', 'ift_histo_ts', 'ift_histo_a',
#        'ift_histo_hh', 'ift_histo_biocontrole', 'ift_histo_rec_moy_bio',
# ...

# %%
# df_studied = df_can.loc[
#     df_can['intervention_id'].isin(studied_ids)
# ]

df_studied = df_can.sample(100)

# %%
# interventions_intrants
# interventions_cibles_trait
# nb_intrants
# rendement_total

# %%
table_show(pd.melt(df_studied[['intervention_id', 'interventions_cibles_trait', 'interventions_intrants', 'nb_intrants', 'rendement_total']], id_vars=['intervention_id']))

# %%
df = {}

def import_df(df_name, path_data, sep, index_col=None):
    df[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep, index_col=index_col, low_memory=False)

def import_dfs(df_names, path_data, sep = ',', index_col=None, verbose=False):
    for df_name in tqdm(df_names) : 
        if(verbose) :
            print(" - ", df_name)
        import_df(df_name, path_data, sep, index_col=index_col)

# get_intervention_realise_outils_can_context --> intervention_realise
# get_intervention_realise_action_outils_can --> 'intervention_realise', 'action_realise'
# get_intervention_realise_combinaison_outils_can -->  'intervention_realise', 'intervention_realise_restructure', 'combinaison_outil', 'materiel', 'combinaison_outil_materiel'
# get_intervention_realise_culture_outils_can --> 'intervention_realise', 'noeuds_realise', 'connection_realise', 
        # 'plantation_perenne_phases_realise', 
        # 'plantation_perenne_realise', 'composant_culture_concerne_intervention_realise', 
        # 'noeuds_realise_restructure', 'plantation_perenne_realise_restructure',
        # 'ccc_intervention_realise_restructure', 'composant_culture',
        # 'espece', 'variete', 'connection_realise_restructure'
# get_intervention_realise_culture_prec_outils_can --> 'composant_culture', 'espece', 'variete', 'intervention_realise', 
        # 'noeuds_realise', 'connection_realise', 'culture', 
        # 'noeuds_realise_restructure'

tables_entrepot = [
        'intervention_realise', 'action_realise', 'combinaison_outil', 'materiel',
        'noeuds_realise', 'connection_realise', 'plantation_perenne_phases_realise', 'plantation_perenne_realise', 'composant_culture_concerne_intervention_realise',
        'composant_culture', 'espece', 'variete', 'culture', 'intervention_realise_agrege', 'dispositif',
        'semence', 'utilisation_intrant_realise', 'intrant', 'recolte_rendement_prix', 'nuisible_edi', 'adventice'
]

tables_performance = [
    'combinaison_outil_materiel'
]

# import des données de l'entrepôt avec la colonne 'id' en index 
import_dfs(tables_entrepot, ENTREPOT_PATH, sep = ',',index_col='id',verbose=False) 
import_dfs(tables_performance, ENTREPOT_PATH, sep = ',',verbose=False)

# %%
import_dfs(['nuisible_edi'], ENTREPOT_PATH, sep = ',',index_col='id',verbose=False)
# Out:
# 100%|██████████| 1/1 [00:00<00:00, 171.09it/s]
# nuisible_edi

# %%
studied_ids = [
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_c02084a1-61a2-4141-b050-3fe25a93f982',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_7c36c01d-3042-47e3-8c38-60062fa7607e',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_3107f3f9-27aa-4af8-8dfa-9ccce3eaa0ef',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_22064a88-0e66-4eb6-94d1-9dec2983b180',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_ac7f4ecb-81e3-4aec-8403-de68c568495c',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_b6018833-c666-4884-8284-421debd76a92',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_5443d171-2c61-458c-9c32-0204cfada4c7',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_c02084a1-61a2-4141-b050-3fe25a93f982',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_feca9050-fd33-46bc-a086-f4b7604b498b',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_ab208dd0-e6e6-4258-becb-e649983293e4',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_e59fc71d-8497-4f8b-93fd-015ed9973c48',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_403d07b6-b6ff-4fe7-91a4-bf804592797a',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_41d544d4-576c-46c1-88f8-07a1ec726700',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_b33f89ad-3489-4a84-873b-eddafd9db459',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_18e3888d-4727-4d83-9b55-92988f5106bc',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_c18d5610-9ff7-4145-b55e-13bc259cee5b',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_4d738dbc-be4e-4911-a135-e45266c28982',
    'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_1bca5b10-af00-4883-bfb9-52674a4b5da6',
]

# %%
df['intervention_realise_test'] = df['intervention_realise'].loc[
    df['intervention_realise'].index.isin(studied_ids)
]
df['action_realise_test'] = df['action_realise'].loc[
    df['action_realise']['intervention_realise_id'].isin(df['intervention_realise_test'].index)
]


df['combinaison_outil_test'] = df['combinaison_outil'].loc[
    df['combinaison_outil'].index.isin(df['intervention_realise_test']['combinaison_outil_id'])
]
df['combinaison_outil_materiel_test'] = df['combinaison_outil_materiel'].loc[
    df['combinaison_outil_materiel']['combinaison_outil_id'].isin(df['combinaison_outil_test'].index)
]
df['materiel_test'] = df['materiel'].loc[
    df['materiel'].index.isin(df['combinaison_outil_materiel_test']['materiel_id'])
]

df['noeuds_realise_test'] = df['noeuds_realise'].loc[
    (df['noeuds_realise'].index.isin(df['intervention_realise_test']['noeuds_realise_id']))
]

df['connection_realise_test'] = df['connection_realise'].loc[
    (df['connection_realise']['cible_noeuds_realise_id'].isin(df['noeuds_realise_test'].index)) | 
    (df['connection_realise']['source_noeuds_realise_id'].isin(df['noeuds_realise_test'].index)) 
]

df['plantation_perenne_phases_realise_test'] = df['plantation_perenne_phases_realise'].loc[
    df['plantation_perenne_phases_realise'].index.isin(df['intervention_realise_test']['plantation_perenne_phases_realise_id'])
]
df['plantation_perenne_realise_test'] = df['plantation_perenne_realise'].loc[
    df['plantation_perenne_realise'].index.isin(df['plantation_perenne_phases_realise_test']['plantation_perenne_realise_id'])
]
df['composant_culture_concerne_intervention_realise_test'] = df['composant_culture_concerne_intervention_realise'].loc[
    df['composant_culture_concerne_intervention_realise']['intervention_realise_id'].isin(df['intervention_realise_test'].index)
]

df['culture_test'] = df['culture'].loc[
    df['culture'].index.isin(df['noeuds_realise_test']['culture_id'])
]
df['composant_culture_test'] = df['composant_culture'].loc[
    df['composant_culture']['culture_id'].isin(list(df['noeuds_realise_test']['culture_id'])) |
    df['composant_culture']['culture_id'].isin(list(df['plantation_perenne_realise_test']['culture_id'])) |
    df['composant_culture']['culture_id'].isin(list(df['connection_realise_test']['culture_intermediaire_id']))
]

df['espece_test'] = df['espece'].loc[
    df['espece'].index.isin(df['composant_culture_test']['espece_id'])
]
df['variete_test'] = df['variete'].loc[
    df['variete'].index.isin(df['composant_culture_test']['variete_id'])
]

df['intervention_realise_agrege_test'] = df['intervention_realise_agrege'].loc[
    df['intervention_realise_agrege'].index.isin(studied_ids)
]

df['dispositif_test'] = df['dispositif'].loc[
    df['dispositif'].index.isin(df['intervention_realise_agrege_test']['dispositif_id'])
]
df['semence_test'] = df['semence'].loc[
    df['semence']['composant_culture_id'].isin(df['composant_culture_test'].index)
]
df['utilisation_intrant_realise_test'] = df['utilisation_intrant_realise'].loc[
    df['utilisation_intrant_realise']['intervention_realise_id'].isin(df['intervention_realise_test'].index)
]
df['intrant_test'] = df['intrant'].loc[
    df['intrant'].index.isin(df['utilisation_intrant_realise_test']['intrant_id'])
]


df['recolte_rendement_prix_test'] = df['recolte_rendement_prix'].loc[
    df['recolte_rendement_prix']['action_id'].isin(df['action_realise_test'].index)
]

df['utilisation_intrant_cible_test'] = df['utilisation_intrant_cible'].loc[
    df['utilisation_intrant_cible']['utilisation_intrant_id'].isin(df['utilisation_intrant_realise_test'].index)
]
df['nuisible_edi_test'] = df['nuisible_edi'].loc[
    df['nuisible_edi'].index.isin(df['utilisation_intrant_cible_test']['ref_cible_id'])
]
df['adventice_test'] = df['adventice'].loc[
    df['adventice'].index.isin(df['utilisation_intrant_cible_test']['ref_cible_id'])
]

# %%
path='./'
df['recolte_rendement_prix_test'].to_csv(path+'recolte_rendement_prix.csv')
df['intervention_realise_test'].to_csv(path+'intervention_realise'+'.csv')
df['action_realise_test'].to_csv(path+'action_realise'+'.csv')
df['combinaison_outil_test'].to_csv(path+'combinaison_outil'+'.csv')
df['combinaison_outil_materiel_test'].to_csv(path+'combinaison_outil_materiel'+'.csv')
df['materiel_test'].to_csv(path+'materiel'+'.csv')
df['noeuds_realise_test'].to_csv(path+'noeuds_realise'+'.csv')
df['connection_realise_test'].to_csv(path+'connection_realise'+'.csv')
df['plantation_perenne_phases_realise_test'].to_csv(path+'plantation_perenne_phases_realise'+'.csv')
df['plantation_perenne_realise_test'].to_csv(path+'plantation_perenne_realise'+'.csv')
df['composant_culture_concerne_intervention_realise_test'].to_csv(path+'composant_culture_concerne_intervention_realise'+'.csv')
df['composant_culture_test'].to_csv(path+'composant_culture'+'.csv')
df['espece_test'].to_csv(path+'espece'+'.csv')
df['variete_test'].to_csv(path+'variete'+'.csv')
df['culture_test'].to_csv(path+'culture'+'.csv')
df['dispositif_test'].to_csv(path+'dispositif'+'.csv')
df['intervention_realise_agrege_test'].to_csv(path+'intervention_realise_agrege'+'.csv')
df['semence_test'].to_csv(path+'semence'+'.csv')
df['utilisation_intrant_realise_test'].to_csv(path+'utilisation_intrant_realise'+'.csv')
df['intrant_test'].to_csv(path+'intrant'+'.csv')
df['utilisation_intrant_cible_test'].to_csv(path+'utilisation_intrant_cible'+'.csv')
df['adventice_test'].to_csv(path+'adventice'+'.csv')
df['nuisible_edi_test'].to_csv(path+'nuisible_edi'+'.csv')

# %%
studied_id = 'fr.inra.agrosyst.api.entities.effective.EffectiveIntervention_b6018833-c666-4884-8284-421debd76a92'

# %%
df['intervention_realise'].loc[
    studied_id
]

# %%
df['intervention_realise_agrege'].loc[
    studied_id
]['zone_id']

# %%
df['utilisation_intrant_realise_test']

# %%
df['utilisation_intrant_realise'].loc[
    df['utilisation_intrant_realise']['intervention_realise_id'] == studied_id
]

# %%
df['utilisation_intrant_cible']
# Out:
#                                                                                utilisation_intrant_id  \
# id
# fr.inra.agrosyst.api.entities.action.PhytoProdu...                                                NaN
# fr.inra.agrosyst.api.entities.action.PhytoProdu...                                                NaN
# fr.inra.agrosyst.api.entities.action.PhytoProdu...                                                NaN
# fr.inra.agrosyst.api.entities.action.PhytoProdu...                                                NaN
# fr.inra.agrosyst.api.entities.action.PhytoProdu...  fr.inra.agrosyst.api.entities.action.Pesticide...
# ...                                                                                               ...
# fr.inra.agrosyst.api.entities.action.PhytoProdu...  fr.inra.agrosyst.api.entities.action.Pesticide...
# fr.inra.agrosyst.api.entities.action.PhytoProdu...  fr.inra.agrosyst.api.entities.action.Pesticide...
# ...

# %%
df['utilisation_intrant_realise']
