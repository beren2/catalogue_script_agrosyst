# %% [markdown]
# #### Import des librairies

# %%
import pandas as pd
from tqdm import tqdm
import numpy as np

# %%
ENTREPOT_PATH = '~/Bureau/utils/data/'
DIRODUR_FILES_PATH = '~/Bureau/projets/DIRODUR/magasin/'
df = {}

# %% [markdown]
# #### Import des données

# %%
# ----------------------------- #
# IMPORT DES DONNÉES DATAGROSYST#
# ----------------------------- #


def import_df(df_name, path_data, sep, index_col=None):
    df[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep, index_col=index_col, low_memory=False).replace({'\r\n': '\n'}, regex=True)

def import_dfs(df_names, path_data, sep = ',', index_col=None, verbose=False):
    for df_name in tqdm(df_names) : 
        if(verbose) :
            print(" - ", df_name)
        import_df(df_name, path_data, sep, index_col=index_col)

tables_with_id = [
    'parcelle',
    'sdc'
]

tables_without_id = [
]

# import des données de l'entrepôt avec la colonne 'id' en index 
import_dfs(tables_with_id, ENTREPOT_PATH, sep = ',', index_col='id', verbose=False)

# import des données du magasin
import_dfs(tables_without_id, ENTREPOT_PATH, sep = ',', verbose=False)
# Out:
# 100%|██████████| 2/2 [00:08<00:00,  4.32s/it]
# 0it [00:00, ?it/s]

# %%
df['sdc'].sample(10).index
# Out:
# Index(['fr.inra.agrosyst.api.entities.GrowingSystem_ca60d1f4-7baa-4d91-8e4c-e14e49fc3c32',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_b17c717f-580c-49d3-ae1a-7dea744a383e',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_4b0fc10f-e681-4c0c-baee-9f607adc007b',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_d7df80b0-8f3e-44f8-a029-ba147732a2b6',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_8fcc4cc3-e82f-4cc8-a9d9-376f6574d085',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_3828a6fd-b7c2-4fcb-a014-568415f78a4f',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_2cd31387-7423-4a70-9b14-1547a3357e83',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_63dd16da-8e5c-4d00-a1e2-d9e26899743c',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_01babaa6-ac75-44d2-98a2-6f0e274170cd',
#        'fr.inra.agrosyst.api.entities.GrowingSystem_d561b593-bced-480a-ba4c-e484bd258afa'],
#       dtype='object', name='id')

# %%
studied_ids = [
       'fr.inra.agrosyst.api.entities.GrowingSystem_ca60d1f4-7baa-4d91-8e4c-e14e49fc3c32',
       'fr.inra.agrosyst.api.entities.GrowingSystem_b17c717f-580c-49d3-ae1a-7dea744a383e',
       'fr.inra.agrosyst.api.entities.GrowingSystem_4b0fc10f-e681-4c0c-baee-9f607adc007b',
       'fr.inra.agrosyst.api.entities.GrowingSystem_d7df80b0-8f3e-44f8-a029-ba147732a2b6',
       'fr.inra.agrosyst.api.entities.GrowingSystem_8fcc4cc3-e82f-4cc8-a9d9-376f6574d085',
       'fr.inra.agrosyst.api.entities.GrowingSystem_3828a6fd-b7c2-4fcb-a014-568415f78a4f',
       'fr.inra.agrosyst.api.entities.GrowingSystem_2cd31387-7423-4a70-9b14-1547a3357e83',
       'fr.inra.agrosyst.api.entities.GrowingSystem_63dd16da-8e5c-4d00-a1e2-d9e26899743c',
       'fr.inra.agrosyst.api.entities.GrowingSystem_01babaa6-ac75-44d2-98a2-6f0e274170cd',
       'fr.inra.agrosyst.api.entities.GrowingSystem_d561b593-bced-480a-ba4c-e484bd258afa'
]

# %%
df['sdc_test'] = df['sdc'].loc[
    df['sdc'].index.isin(studied_ids)
]

# %%
df['parcelle_test'] = df['parcelle'].loc[
    df['parcelle']['sdc_id'].isin(df['sdc_test'].index)
]

# %%
path='./'
df['sdc_test'].to_csv(path+'sdc'+'.csv')
df['parcelle_test'].to_csv(path+'parcelle'+'.csv')
