# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd

ENTREPOT_PATH = 'C:/Users/lubaude/Desktop/utils/data/'
DATA_TEST_PATH = './'
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def import_df(df_name, path_data, sep, df):
    """
        importe un dataframe au chemin path_data+df_name+'.csv' et le stock dans le dictionnaire 'df' à la clé df_name
    """
    df[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep).replace({'\r\n': '\n'}, regex=True)

def import_dfs(df_names, path_data,  df, sep = ','):
    """
        stocke dans le dictionnaire df tous les dataframes indiqués dans la liste df_names
    """
    for df_name in df_names : 
        import_df(df_name, path_data, sep, df)
    return df

df_names =  [   'sdc',
                'parcelle',
                'zone',
                'synthetise',
                'dispositif',
                'domaine',
                'intervention_synthetise_agrege',
                'intervention_realise_agrege'
            ]


donnees = import_dfs(df_names, ENTREPOT_PATH, {}, sep = ',')
# Out:
# C:\Users\lubaude\AppData\Local\Temp\ipykernel_22048\881043171.py:5: DtypeWarning: Columns (2,3,4,7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep).replace({'\r\n': '\n'}, regex=True)
# C:\Users\lubaude\AppData\Local\Temp\ipykernel_22048\881043171.py:5: DtypeWarning: Columns (7,8) have mixed types. Specify dtype option on import or set low_memory=False.
#   df[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep).replace({'\r\n': '\n'}, regex=True)

# %%
studied_ids = ['fr.inra.agrosyst.api.entities.practiced.PracticedSystem_3bef9322-3a5d-4b72-a7e4-751c91c67674',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_09b27352-c38c-4e3a-b1bd-5081938b7581',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_da9b084b-24bd-427d-96fa-0d2ad8e261a1',
               'fr.inra.agrosyst.api.entities.Zone_1842112a-4bb0-452c-a511-1b60be72d12c',
               'fr.inra.agrosyst.api.entities.Zone_e6bfd200-4968-4de7-884e-93ab57513e05',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_03512b7f-8aa0-4bb6-9e91-ecf232a4e39a',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_19af9c4e-a656-44d0-abdf-39ecb589f8c7',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_5bc82306-16bc-44bf-b5df-e0246aae1718',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_854cbd37-7525-45ef-9961-c0222afdbd3c',
               'fr.inra.agrosyst.api.entities.Zone_9a48c09c-32b9-4af7-81d3-d677510c5ed1',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_a75d4cb6-ee75-4848-95ea-ff44cf920b2b',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_d66123f3-9559-4d53-b742-dc7c9a6bd0be',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_684d2be0-f7d7-43db-84cb-ac4da50f3484',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_b9137c21-d217-4f08-b395-2cb1e8e914ac',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_65cc4830-b50c-429a-a3c7-ad500962bd14',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_8f6a24cc-85ff-4ab9-b4d0-cfde684c41ae',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_54c3f70e-b0a3-4e99-a787-f48c50d38124',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_cdae7e9e-81b5-4d18-bb4f-b888c82cfa94',
               'fr.inra.agrosyst.api.entities.Zone_2066674a-644f-4da2-a91f-a790d98acd7ds',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_bda297a1-f4cf-4da1-8281-c1b512359b20',
               'fr.inra.agrosyst.api.entities.Zone_86b86082-2a63-412b-bf00-4507d8a9326e',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_ba3c39b7-1a22-4b36-965a-33cf70b22553',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_a7dac827-2f1a-476f-ac54-67b18d5e582f',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_513d56b7-63d2-40d3-a3c8-b13def70c327',
               'fr.inra.agrosyst.api.entities.Zone_53764c41-64c6-4821-b06d-7d97ea4034ec',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_75a9cf63-ce93-4f07-959e-ced39c97aa44',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_b0039d0d-42e3-443b-af15-5497a8aaa16d',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_db04d57a-868b-4051-975d-5478e3afc31c',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_3423ed38-304c-4c03-a7eb-2ec4706dd30b',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_2a263a39-4811-484c-aa35-cb805d0ecb86',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_7ecf458e-1c1d-4e94-a5ba-442f2150b279',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_3bf5464b-c15d-4305-be3c-48e6325c817e',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_ce0ba174-fbd9-4e63-bdca-dfc53e612587',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_97977081-9327-4eb5-b478-895d0a1daba3',
               'fr.inra.agrosyst.api.entities.practiced.PracticedSystem_626bce3b-807b-4f09-83eb-50b0c1d49359',
               'fr.inra.agrosyst.api.entities.Zone_834a10d1-d938-469b-9d0e-498b1a7138c8']

# %%
# dict : 
# cle : nom de la table a filtrer
# value : liste 0 : 'col_interne' si la colonne qui permet de filtrer est au sein du data à filtrer SINON 'col_externe' : 
#           liste 1 : table qui permet de filtrer , peut etre une liste de tables
#           liste 2 : colonne qui permet de filtrer de element 0

# ex1 : 'domaine' : ['col_externe','parcelle','domaine_id']
# ex2 : 'noeuds_realise' : ['col_interne','zone','zone_id']
# ex3 avec plusieurs tables qui permettent de filtrer: 'sdc' : ['col_externe',['zone','synthetise'],'sdc_id']

lien_entre_table = {'parcelle' : ['col_externe','zone','parcelle_id'],
                    'sdc' : ['col_externe',['parcelle','synthetise'],'sdc_id'],
                    'dispositif' : ['col_externe','sdc','dispositif_id'],
                    'domaine' : ['col_externe','dispositif','domaine_id'],
                    'intervention_synthetise_agrege' : ['col_interne','synthetise','synthetise_id'],
                    'intervention_realise_agrege' : ['col_interne','zone','zone_id']
}

data_filtre = donnees.copy()
data_filtre['zone'] = data_filtre['zone'].loc[data_filtre['zone']['id'].isin(studied_ids)]
data_filtre['synthetise'] = data_filtre['synthetise'].loc[data_filtre['synthetise']['id'].isin(studied_ids)]

print(data_filtre['zone'].shape)
print(data_filtre['synthetise'].shape)

def filtre_table(type_filtre,data_filtre,table_a_filtrer,table_filtre,colonne_pour_filtrer):
    if type_filtre == 'col_interne':
        res = data_filtre[table_a_filtrer].loc[data_filtre[table_a_filtrer][colonne_pour_filtrer].isin(data_filtre[table_filtre]['id'])]
    else :
        res = data_filtre[table_a_filtrer].loc[data_filtre[table_a_filtrer]['id'].isin(data_filtre[table_filtre][colonne_pour_filtrer])]
    return(res)

# parcours du dict des liens entre table pour filtrer progressivement les donnees lies aux id choisis
for key in lien_entre_table.keys() :
    table_a_filtrer = key
    print(table_a_filtrer)
    type_filtre = lien_entre_table[key][0]
    table_filtre = lien_entre_table[key][1]
    colonne_pour_filtrer = lien_entre_table[key][2]

    print(data_filtre[table_a_filtrer].shape)
    if type(table_filtre) == list: # cas avec plusieurs tables filtres
        temp = filtre_table(type_filtre,data_filtre,table_a_filtrer,table_filtre[0],colonne_pour_filtrer)
        for t in table_filtre[1:len(table_filtre)] :
            temp = pd.concat([temp, filtre_table(type_filtre,data_filtre,table_a_filtrer,t,colonne_pour_filtrer)])
        data_filtre[table_a_filtrer] = temp
    else : 
        data_filtre[table_a_filtrer] = filtre_table(type_filtre,data_filtre,table_a_filtrer,table_filtre,colonne_pour_filtrer)

    print(data_filtre[table_a_filtrer].shape)
# Out:
# (11, 9)
# (52, 8)
# parcelle
# (221941, 49)
# (11, 49)
# sdc
# (35309, 92)
# (61, 92)
# dispositif
# (30455, 6)
# (60, 6)
# domaine
# (29516, 37)
# (60, 37)
# intervention_synthetise_agrege
# (1214233, 12)
# (3885, 12)
# intervention_realise_agrege
# (1236963, 12)
# (122, 12)

# %%
# selectionner seulement 1 ligne de intervention de chaque synthetise ou zone pour ne pas prendre trop de place

data_filtre['intervention_synthetise_agrege'] = data_filtre['intervention_synthetise_agrege'].groupby('synthetise_id').head(2).reset_index()
data_filtre['intervention_realise_agrege'] = data_filtre['intervention_realise_agrege'].groupby('zone_id').head(2).reset_index()

# %%
data_filtre['intervention_realise_agrege']
# Out:
#      index  Unnamed: 0                                                 id  \
# 0    33077       33077  fr.inra.agrosyst.api.entities.effective.Effect...
# 1    47288       47288  fr.inra.agrosyst.api.entities.effective.Effect...
# 2    52588       52588  fr.inra.agrosyst.api.entities.effective.Effect...
# 3    78797       78797  fr.inra.agrosyst.api.entities.effective.Effect...
# 4    88794       88794  fr.inra.agrosyst.api.entities.effective.Effect...
# 5   120683      120683  fr.inra.agrosyst.api.entities.effective.Effect...
# 6   131035      131035  fr.inra.agrosyst.api.entities.effective.Effect...
# 7   160364      160364  fr.inra.agrosyst.api.entities.effective.Effect...
# 8   249137      249137  fr.inra.agrosyst.api.entities.effective.Effect...
# 9   250010      250010  fr.inra.agrosyst.api.entities.effective.Effect...
# 10  261139      261139  fr.inra.agrosyst.api.entities.effective.Effect...
# 11  398906      398906  fr.inra.agrosyst.api.entities.effective.Effect...
# ...

# %%
# dict : colonnes a garder dans le data set
# cle : nom de la table
# value : liste de colonnes a garder
colonnes_utiles = {
    'synthetise' : ['id', 'sdc_id','campagnes'],
    'zone' : ['id', 'parcelle_id'],
    'parcelle' : ['id', 'sdc_id'],
    'dispositif' : ['id','type','domaine_id','campagne'],
    'sdc' : ['id','dispositif_id','modalite_suivi_dephy','code_dephy','campagne'],
    'domaine' : ['id','campagne'],
    'intervention_synthetise_agrege' : ['id','sdc_id','synthetise_id'],
    'intervention_realise_agrege' : ['id','sdc_id','zone_id']
    }

# retirer les colonnes inutiles et imprimer en csv

for d in data_filtre :
    colonnes_to_keep = colonnes_utiles[d]
    data_filtre[d][colonnes_to_keep].to_csv(DATA_TEST_PATH+d+'.csv',index=False)
