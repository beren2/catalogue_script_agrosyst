# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
from tqdm import tqdm

# %%
ENTREPOT_PATH = "/home/tbadie/Bureau/data/data_entrepot_outils/"
PATH_TEMP = "/home/tbadie/Bureau/data/temp/typologie_dirodur/"
donnees = {}

def import_df(df_name, path_data, sep, index_col=None):
    donnees[df_name] = pd.read_csv(path_data+df_name+'.csv', sep = sep, index_col=index_col, low_memory=False).replace({'\r\n': '\n'}, regex=True)

def import_dfs(df_names, path_data, sep = ',', index_col=None, verbose=False):
    for df_name in tqdm(df_names) : 
        if(verbose) :
            print(" - ", df_name)
        import_df(df_name, path_data, sep, index_col=index_col)

tables = [
    'composant_culture',
    'culture',
    # 'espece'
]

# import des données du magasin
import_dfs(tables, ENTREPOT_PATH, sep = ',', verbose=False)


# donnees['matrice'] = pd.read_csv(PATH_TEMP+"ref_matrice.csv", sep=',')
# donnees['espece'] = pd.read_csv(PATH_TEMP+"ref_espece_gcpe.csv", sep=',')
donnees['espece'] = pd.read_csv(PATH_TEMP+"ref_espece_gcpe_thomas.csv", sep=',')
# Out:
# 100%|██████████| 2/2 [00:03<00:00,  1.78s/it]

# %%
# def get_typologie_typodirodur_culture(donnees):
#     ''' 
#     Le but est d'obtenir les typologies d'espece et de culture utilisées par DIRODUR.

#     Note(s):
#         La typologie espece a été directement intégré au référentiel refespece d'Agrosyst

#     Echelle :
#         culture_id

#     Args:
#         donnees (dict):
#             Données d'entrepot
#             - 'composant_culture'
#             - 'culture'
#             - 'espece'
#             - 'recolte_rendement_prix'
#             - 'recolte_rendement_prix_restructure'
#             Données externe (référentiel CAN):
#             - 'matrice_passage_esp_typodirodur_culture.csv'

#     Returns:
#         pd.DataFrame() contenant la culture_id et la typologie de culture de la CAN
#     '''

# %%
# Donnes de bases
# TODO : .reset_index() avant copy()) si le test marche pas
cropsp = donnees['composant_culture'].copy()
cropsp = cropsp[['id','espece_id','culture_id','compagne']].rename(columns={'id':'composant_culture_id'})
crop = donnees['culture'].copy()
crop = crop[['id','nom','type']].rename(columns={'id':'culture_id'})
sp = donnees['espece'].copy()
sp = sp[['id','typodirodur_espece','typodirodur_espece_precise','typodirodur_espece_famille_bota','typodirodur_espece_periode_semis']].rename(columns={'id':'espece_id'})
# TODO matrice = donnees['matrice'].copy()


df = cropsp.merge(sp, how = 'left', on = 'espece_id')
# Liste des cultures qui contiennent des cultures compagnes
list_culture_with_compagne = list(set(df.loc[df['compagne'].notnull(), 'culture_id']))

df['nb_composant_culture'] = 1
df['nb_typodirodur_espece_precise'] = df['typodirodur_espece_precise'].copy()
df['nb_typodirodur_espece'] = df['typodirodur_espece'].copy()
df['nb_typodirodur_espece_famille_bota'] = df['typodirodur_espece_famille_bota'].copy()

def concat_unique_sorted(series):
    cleaned = series.dropna().unique()
    if len(cleaned) == 0:
        return np.nan
    return '_'.join(sorted(cleaned))

def get_nb_unique_typo(series):
    cleaned = series.dropna().unique()
    return len(cleaned)

agg_dict = {
    'nb_composant_culture': 'sum',
    'typodirodur_espece': concat_unique_sorted,
    'typodirodur_espece_precise': concat_unique_sorted,
    'typodirodur_espece_famille_bota': concat_unique_sorted,
    'typodirodur_espece_periode_semis': concat_unique_sorted,
    'nb_typodirodur_espece': get_nb_unique_typo,
    'nb_typodirodur_espece_precise': get_nb_unique_typo,
    'nb_typodirodur_espece_famille_bota': get_nb_unique_typo,
}

# %%
# # lister les cultures de la filiere GCPE

# tables = [
#     'sdc',
#     'noeuds_realise',
#     'connection_realise',
#     'noeuds_synthetise',
#     'noeuds_synthetise_restructure',
#     'connection_synthetise',
#     'connection_synthetise_restructure',
#     'zone',
#     'parcelle',
#     'synthetise',
#     'plantation_perenne_realise',
#     'plantation_perenne_synthetise_restructure'
# ]

# # import des données du magasin
# import_dfs(tables, ENTREPOT_PATH, sep = ',', verbose=False)



# def get_all_gcpe_culture_id(donnees) :
#     sdc = donnees['sdc'][['id','filiere']].copy()
#     nodeR = donnees['noeuds_realise'][['id', 'culture_id', 'zone_id']].copy()
#     cnxR = donnees['connection_realise'][['id', 'cible_noeuds_realise_id', 'culture_intermediaire_id']].copy().rename(columns={'cible_noeuds_realise_id': 'noeuds_realise_id'})
#     nodeS = donnees['noeuds_synthetise'][['id', 'synthetise_id']].copy()
#     nodeS_rest = donnees['noeuds_synthetise_restructure'].copy()
#     cnxS = donnees['connection_synthetise'][['id','cible_noeuds_synthetise_id']].copy().rename(columns={'cible_noeuds_synthetise_id': 'noeuds_synthetise_id'})
#     cnxS_rest = donnees['connection_synthetise_restructure'][['id','culture_intermediaire_id']].copy()
#     zone = donnees['zone'][['id','parcelle_id']].copy()
#     parcelle = donnees['parcelle'][['id','sdc_id']].copy()
#     synthetise = donnees['synthetise'][['id','sdc_id']].copy()
#     plantation_perenne_realise = donnees['plantation_perenne_realise'][['id','culture_id']].copy()
#     plantation_perenne_synthetise_restructure = donnees['plantation_perenne_synthetise_restructure'][['id','culture_id']].copy()



#     cnxR = cnxR.merge(nodeR.rename(columns={'id':'noeuds_realise_id'}), on='noeuds_realise_id', how='left')
#     cnxR = cnxR.loc[cnxR['culture_intermediaire_id'].notnull(), ['id','culture_intermediaire_id','zone_id']].rename(columns={'culture_intermediaire_id':'culture_id'})

#     cnxS = cnxS.merge(cnxS_rest, on='id', how='left').merge(nodeS.rename(columns={'id':'noeuds_synthetise_id'}), on ='noeuds_synthetise_id', how='left')
#     cnxS = cnxS.loc[cnxS['culture_intermediaire_id'].notnull(), ['id','culture_intermediaire_id','synthetise_id']].rename(columns={'culture_intermediaire_id':'culture_id'})


#     real = pd.concat([nodeR, plantation_perenne_realise, cnxR])
#     syn = pd.concat([nodeS_rest, plantation_perenne_synthetise_restructure, cnxS])

#     real = real.merge(zone.rename(columns={'id': 'zone_id'}), on='zone_id', how='left')
#     real = real.merge(parcelle.rename(columns={'id': 'parcelle_id'}), on='parcelle_id', how='left')
#     syn = syn.merge(synthetise.rename(columns={'id': 'synthetise_id'}), on='synthetise_id', how='left')

#     df = pd.concat([real, syn])
#     df = df.merge(sdc.rename(columns={'id': 'sdc_id'}), on='sdc_id', how = 'left')

#     df = df.loc[df['filiere'].isin(['GRANDES_CULTURES','POLYCULTURE_ELEVAGE'])]

#     return df['culture_id'].unique().tolist()

# list_cid_gcpe = get_all_gcpe_culture_id(donnees)
# Out:
# 100%|██████████| 12/12 [00:09<00:00,  1.24it/s]

# %%
df
# Out:
#                                      composant_culture_id  \
# 0       fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 1       fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 2       fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 3       fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 4       fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# ...                                                   ...
# 382435  fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 382436  fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 382437  fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 382438  fr.inra.agrosyst.api.entities.CroppingPlanSpec...
# 382439  fr.inra.agrosyst.api.entities.CroppingPlanSpec...
#
#                                                 espece_id  \
# 0       fr.inra.agrosyst.api.entities.referential.RefE...
# 1       fr.inra.agrosyst.api.entities.referential.RefE...
# 2       fr.inra.agrosyst.api.entities.referential.RefE...
# ...

# %%
#  On crée les typologie can culture et les autre variable utiles grace a agg_dict
df = df[['culture_id',
         'nb_composant_culture',
         'typodirodur_espece',
         'typodirodur_espece_precise',
         'typodirodur_espece_famille_bota',
         'typodirodur_espece_periode_semis',
         'nb_typodirodur_espece',
         'nb_typodirodur_espece_precise',
         'nb_typodirodur_espece_famille_bota']].groupby('culture_id').agg(agg_dict).reset_index()

# On ajoute les type des culture_id
# On fait un outer pour avoir toutes les cultures meme celles qui n'ont pas de composant_culture
df = df.merge(crop[['culture_id','nom','type']], how='outer', on='culture_id')

# Détection des cultures qui contiennent des cultures compagnes
df['is_any_compagne'] = np.where(df['culture_id'].isin(list_culture_with_compagne), True, False)

df.loc[df['nb_composant_culture'].isna(),['nb_composant_culture','nb_typodirodur_espece','nb_typodirodur_espece_precise','nb_typodirodur_espece_famille_bota']] = 0

# On ne garde que les cultures de la filiere GCPE
df = df.loc[df['culture_id'].isin(list_cid_gcpe)]

# %%
df.head(10)
# Out:
#                                            culture_id  nb_composant_culture  \
# 5   fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
# 6   fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   4.0
# 8   fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   2.0
# 12  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
# 13  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   2.0
# 14  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
# 17  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
# 20  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
# 21  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   0.0
# 22  fr.inra.agrosyst.api.entities.CroppingPlanEntr...                   1.0
#
#                     typodirodur_espece  \
# 5                           Ble tendre
# 6   Crucifere_Moutarde_Sarrasin_Trefle
# ...

# %%
# Donnees d'intervention pour les dates de semis

tables = [
    'intervention_synthetise',
    'intervention_realise',
    'noeuds_realise',
    'noeuds_synthetise',
    'noeuds_synthetise_restructure',
    'connection_synthetise',
    'zone',
    'parcelle',
    'synthetise',
    'sdc'
]

# import des données du magasin
import_dfs(tables, ENTREPOT_PATH, sep = ',', verbose=False)

def get_sowing_date(donnees) :
    """
    Calcule une date moyenne de semis par culture à partir des interventions date_din et date_début des interventions de semis en réalisées et synthétisées.
    """

    # Chargement des tables utiles
    intv_S = donnees['intervention_synthetise'][['id','type','date_debut','date_fin','concerne_ci','connection_synthetise_id']].copy()
    intv_R = donnees['intervention_realise'][['id','type','date_debut','date_fin','concerne_ci','noeuds_realise_id']].copy()
    conx_S = donnees['connection_synthetise'][['id','cible_noeuds_synthetise_id']].rename(columns={'id':'connection_synthetise_id', 'cible_noeuds_synthetise_id':'noeuds_synthetise_id'}).copy()
    noeud_w_culture_id_S = donnees['noeuds_synthetise_restructure'][['id','culture_id']].rename(columns={'id':'noeuds_synthetise_id'}).copy()
    noeuds_w_culture_id_R = donnees['noeuds_realise'][['id','culture_id','zone_id']].rename(columns={'id':'noeuds_realise_id'}).copy()

    node_S = donnees['noeuds_synthetise'][['id','synthetise_id']].rename(columns={'id':'noeuds_synthetise_id'}).copy()
    synthe = donnees['synthetise'][['id','sdc_id']].rename(columns={'id':'synthetise_id'}).copy()
    zone = donnees['zone'][['id','parcelle_id']].rename(columns={'id':'zone_id'}).copy()
    parcelle = donnees['parcelle'][['id','sdc_id']].rename(columns={'id':'parcelle_id'}).copy()
    sdc = donnees['sdc'][['id','filiere']].rename(columns={'id':'sdc_id'}).copy()

    # Filtre sur les interventions de semis hors CI
    intv_S = intv_S.loc[(intv_S['type'] == 'SEMIS') & 
                        (intv_S['connection_synthetise_id'].notna()) & 
                        (intv_S['concerne_ci'] == 'f')]
    intv_R = intv_R.loc[(intv_R['type'] == 'SEMIS') & 
                        (intv_R['noeuds_realise_id'].notna()) & 
                        (intv_R['concerne_ci'] == 'f')]

    # Rattachement des cultures
    intv_S = intv_S.merge(conx_S, on='connection_synthetise_id', how='left')
    intv_S = intv_S.merge(noeud_w_culture_id_S, on='noeuds_synthetise_id', how='left')
    intv_R = intv_R.merge(noeuds_w_culture_id_R, on='noeuds_realise_id', how='left')


    def moyenne_dates(start_series, end_series, methode = 'R'):
        """ 
        Calcule la date moyenne entre date_debut et date_fin.
        """

        def parse_S_date(s):
            """ 
            Créer une date au format date. 
            Affecter une année pour avoir une vrai date. 
            On corrige le jour dans le cas des années bissextile et des erreurs de saisie 
            """
            j, m = map(int, s.split('/'))
            try :
                return datetime(2025, m, j)
            except ValueError:
                try : 
                    return datetime(2025, m, j-1)
                except ValueError:
                    return datetime(2025, m, j-2)
                
        def parse_R_date(s):
            """ 
            Créer une date au format date. 
            """
            y, m, j = map(int, s.split('-'))
            return datetime(y, m, j)
        
        # Cas ou les dates de fin sont antérieures aux dates de début
        if methode == 'S':
            start_dates = start_series.apply(parse_S_date)
            end_dates = end_series.apply(parse_S_date)

            mask = end_dates < start_dates
            end_dates.loc[mask] = end_dates.loc[mask].apply(lambda x: datetime(2026, x.month, x.day))

        elif methode == 'R':
            start_dates = start_series.apply(parse_R_date)
            end_dates = end_series.apply(parse_R_date)

        # Moyenne
        moyennes = start_dates + ((end_dates - start_dates) / 2)

        # Retourne la date au format jj/mm
        return moyennes.dt.strftime('%d/%m')

    # Date de semis moyenne par intervention
    intv_R['date_semis'] = moyenne_dates(intv_R['date_debut'], intv_R['date_fin'], methode='R')
    intv_S['date_semis'] = moyenne_dates(intv_S['date_debut'], intv_S['date_fin'], methode='S')

    # Fusion des données réalisées et synthétisées
    intv = pd.concat([intv_S, intv_R], ignore_index=True)

    # Rattachement au SDC puis filtrage sur GCPE
    intv = intv.merge(node_S, on='noeuds_synthetise_id',how='left')
    intv = intv.merge(synthe, on='synthetise_id',how='left')
    intv = intv.merge(zone, on='zone_id',how='left')
    intv = intv.merge(parcelle, on='parcelle_id',how='left')
    intv['sdc_id'] = np.where(intv['sdc_id_x'].notna(), intv['sdc_id_x'], intv['sdc_id_y'])
    intv = intv[['id','culture_id','date_semis','sdc_id']]
    intv = intv.merge(sdc, on='sdc_id',how='left')
    intv = intv.loc[intv['filiere'].isin(['POLYCULTURE_ELEVAGE','GRANDES_CULTURES'])]

    # Conversion en jour de l'année pour calcul circulaire
    # PS : Ajouter une année bissextile (2020) pour parser les dates
    intv['_dayofyear'] = pd.to_datetime(
        intv['date_semis'].astype(str) + '/2020',
        format='%d/%m/%Y'
    ).dt.dayofyear

    # Fonction pour trier un groupe en boucle circulaire
    def circular_mean_date(group):
        """
        Moyenne de dates en tenant compte du passage au nouvel an (ex: 30/12, 01/01, 02/01 => date moyenne = 01/01).
        """

        days = group['_dayofyear'].values
        if len(list(set(days))) == 1:
            return pd.Series({
                'dates_nbjr_triees': days.tolist(),
                'date_moyenne': group['date_semis'].values[0]
            })

        # Trouve l'écart maximal entre 2 dates consécutives (en boucle)
        sorted_days = np.sort(days)
        diffs = np.diff(np.r_[sorted_days, sorted_days[0] + 366])  # +366 pour gérer 29/02
        cut = np.argmax(diffs)+1
        # Réordonne en partant après la coupure
        order = np.roll(sorted_days, -cut)

        # Retourne la date moyenne
        asc_list = [y + order[0] if y < order[0] else y for y in order]
        moy = np.mean(asc_list)
        if moy > 366:
            moy -= 366
        date_moy = datetime(2020, 1, 1) + timedelta(days=moy-1)
        date_moy = date_moy.strftime('%d/%m') 

        return pd.Series({
            'dates_nbjr_triees': order.tolist(),
            'date_moyenne': date_moy
        })
    
    # Applique la fonction circular_mean_date et retourner l'objet
    return intv.groupby('culture_id', group_keys = False).apply(circular_mean_date, include_groups=False)

semis = get_sowing_date(donnees)
# Out:
# 100%|██████████| 10/10 [00:30<00:00,  3.02s/it]

# %%
def get_sowing_season(date_str):
    """ 
    A partir d'une date au format jj/mm, retourne la saison de semis correspondante.
    """

    j, m = map(int, date_str.split('/'))
    date = datetime(2024, m, j)
    if datetime(2024, 1, 16) <= date <= datetime(2024, 4, 15):
        return 'printemps'
    elif datetime(2024, 4, 16) <= date <= datetime(2024, 6, 15):
        return 'ete'
    elif datetime(2024, 6, 16) <= date <= datetime(2024, 9, 15):
        return 'automne'
    else:
        return 'hiver'


semis['saison_semis'] = semis['date_moyenne'].apply(get_sowing_season)
df = df.merge(semis, how = 'left', on = 'culture_id')

# %%
df['type'] = df['type'].astype('category')
df['type'] = df['type'].cat.rename_categories({'MAIN': 'principale', 
                                                'INTERMEDIATE': 'intermediaire', 
                                                'CATCH': 'derobee' })
df['type'] = df['type'].astype('str')
df[['nb_composant_culture','nb_typodirodur_espece_precise','nb_typodirodur_espece_famille_bota']] = df[['nb_composant_culture','nb_typodirodur_espece_precise','nb_typodirodur_espece_famille_bota']].astype('int64')

# %%
# df.to_csv(PATH_TEMP+"typodirodur_culture.csv", sep=',', index=False)
df
# Out:
#                                               culture_id  \
# 0      fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 1      fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 2      fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 3      fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 4      fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# ...                                                  ...
# 62539  fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 62540  fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 62541  fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 62542  fr.inra.agrosyst.api.entities.CroppingPlanEntr...
# 62543  fr.inra.agrosyst.api.entities.CroppingPlanEntr...
#
#        nb_composant_culture                  typodirodur_espece  \
# 0                         1                          Ble tendre
# 1                         4  Crucifere_Moutarde_Sarrasin_Trefle
# 2                         2                     Avoine_Phacelie
# ...

# %%
df.value_counts('typodirodur_espece')
# Out:
# typodirodur_espece
# Ble tendre                                  11630
# Mais                                         7660
# Orge                                         6157
# Colza                                        4176
# Prairie                                      2754
#                                             ...
# Colza_Feverole_Lentille_Tournesol_Trefle        1
# Colza_Feverole_Lentille_Trefle                  1
# Colza_Feverole_Lentille_Trefle_Vesce            1
# Colza_Feverole_Lin_Phacelie_Trefle              1
# Colza_Fenugrec_Feverole_Lentille_Trefle         1
# Name: count, Length: 1380, dtype: int64

# %%
df.columns
# Out:
# Index(['culture_id', 'nb_composant_culture', 'typodirodur_espece',
#        'typodirodur_espece_precise', 'typodirodur_espece_famille_bota',
#        'typodirodur_espece_periode_semis', 'nb_typodirodur_espece',
#        'nb_typodirodur_espece_precise', 'nb_typodirodur_espece_famille_bota',
#        'nom', 'type', 'is_any_compagne', 'dates_nbjr_triees', 'date_moyenne',
#        'saison_semis'],
#       dtype='object')

# %%
def unique_sorted(series):
    unique = series.value_counts(dropna=False).sort_values(ascending=False)
    return unique.keys().to_list()

matrice_thomas = df.groupby('typodirodur_espece').agg({
    'culture_id': 'count',
    'type' : unique_sorted,
    'typodirodur_espece_periode_semis' : unique_sorted,
    'typodirodur_espece_precise': unique_sorted,
    'saison_semis' : unique_sorted,
}).rename(columns={'culture_id':'count'}).sort_values(by='count', ascending=False)

# %%
matrice_mae = pd.read_csv(PATH_TEMP+"ref_matrice.csv", sep=',', index_col=0)

matrice_thomas = matrice_thomas.explode('typodirodur_espece_precise')
matrice_thomas.reset_index(inplace=True)

result = matrice_thomas.merge(
    matrice_mae,
    on='typodirodur_espece_precise',
    how='left'
)
result
# Out:
#                             typodirodur_espece  count  \
# 0                                   Ble tendre  11630
# 1                                   Ble tendre  11630
# 2                                   Ble tendre  11630
# 3                                   Ble tendre  11630
# 4                                   Ble tendre  11630
# ...                                        ...    ...
# 2660  Colza_Feverole_Lentille_Tournesol_Trefle      1
# 2661            Colza_Feverole_Lentille_Trefle      1
# 2662      Colza_Feverole_Lentille_Trefle_Vesce      1
# 2663        Colza_Feverole_Lin_Phacelie_Trefle      1
# 2664   Colza_Fenugrec_Feverole_Lentille_Trefle      1
#
#                                       type  \
# 0     [principale, intermediaire, derobee]
# 1     [principale, intermediaire, derobee]
# 2     [principale, intermediaire, derobee]
# 3     [principale, intermediaire, derobee]
# 4     [principale, intermediaire, derobee]
# ...                                    ...
# ...

# %%
cols_t = [
    'count',
    'type',
    'typodirodur_espece_periode_semis',
    'saison_semis',
    'typodirodur_espece_precise'
]

cols_m = [
    'typodirodur_culture',
    'culture_est_avec_compagne',
    'culture_est_annuelle_asso',
    'culture_est_prairie',
]

# Colonnes à agréger
cols = list(cols_t + cols_m)

def unique_sorted_scalar(series):
    s = series.dropna()

    if len(s) == 0:
        return pd.NA

    unique = s.value_counts().sort_values(ascending=False).index.to_list()

    if len(unique) == 1:
        return unique[0]

    return unique

result_agrege = (
    result
    .groupby('typodirodur_espece', dropna=False)
    .agg({col: unique_sorted_scalar for col in cols if col in result.columns})
    .reset_index()
)
result_agrege
# Out:
#                                      typodirodur_espece  count  \
# 0                                             Amaranthe      1
# 1                                            Aromatique     33
# 2     Aromatique_Chia_Crucifere_Fenugrec_Lin_Nyger_P...      1
# 3     Aromatique_Fetuque_Lotier_Paturin_Sainfoin_Sal...      1
# 4                    Aromatique_Fetuque_Sarrasin_Trefle      1
# ...                                                 ...    ...
# 1375                             Trefle_Triticale_Vesce      3
# 1376                                       Trefle_Vesce     10
# 1377                                          Triticale   1043
# 1378                                    Triticale_Vesce      3
# 1379                                              Vesce    134
#
#                                       type  \
# 0                             [principale]
# 1              [principale, intermediaire]
# 2                          [intermediaire]
# ...

# %%
result_agrege['typodirodur_culture'] = np.where((~result_agrege['typodirodur_espece'].str.contains('_')) & 
                                                (result_agrege['typodirodur_culture'].isnull()), 
                                                result_agrege['typodirodur_espece'],
                                                result_agrege['typodirodur_culture'])

result_agrege.sort_values(by='count', ascending=False, inplace=True)
result_agrege.to_csv(PATH_TEMP+"ref_matrice_to_complete.csv", sep=',', index=False)
